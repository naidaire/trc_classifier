# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sns
from sklearn.model_selection import cross_val_score

from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from textblob import TextBlob, Word

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
file = './data/sig_train_data.csv'

classifier = pd.read_csv(file, encoding='latin1')

# %%
classifier.columns = ['question_num', 'question', 'response', 'maturity',
       'misc_info', 'aup_ref', 'iso_num',
       'iso_desc', 'sig_class']

# %%
classifier.head()
# Out:
#   question_num                                           question response  \
# 0          A.1  Is there a risk assessment program that has be...      Yes
# 1        A.1.1  A risk assessment, conducted within the last 1...      Yes
# 2        A.1.2                                   Risk Governance?      Yes
# 3        A.1.3  Range of assets to include: people, processes,...      Yes
# 4        A.1.4  Range of threats to include: malicious, natura...      Yes
#
#    maturity                                          misc_info  \
# 0       5.0  An enterprise risk assessment is performed ann...
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3       NaN                                                NaN
# 4       NaN                                                NaN
#
#                                              aup_ref    iso_num  \
# 0            A.1 IT & Infrastructure Risk Governance  5.1 6.1.2
# 1  A.2 IT & Infrastructure Risk Assessment Life C...        8.2
# 2            A.1 IT & Infrastructure Risk Governance        NaN
# 3            A.1 IT & Infrastructure Risk Governance        NaN
# 4            A.1 IT & Infrastructure Risk Governance      6.1.2
#
#                                             iso_desc        sig_class
# 0  Leadership & Commitment, Information Security ...  Risk Assessment
# 1               Information security risk assessment  Risk Assessment
# 2                                                NaN  Risk Assessment
# 3                                                NaN  Risk Assessment
# 4               Information Security Risk Assessment  Risk Assessment

# %%
classifier.loc[:, 'sig_class'].value_counts()
# Out:
# Application Security                         215
# Operations Management                        120
# Business Resiliency                          105
# Asset and Information Management             104
# Server Security                               96
# Physical and Environment                      86
# End User Device Security                      76
# Access Control                                74
# Network Security                              66
# Incident Event & Communication Management     45
# Risk Assessment                               43
# Security Policy                               42
# Threat Management                             38
# Compliance                                    31
# Human Resource Security                       28
# Privacy                                       18
# Organizational Security                       10
# Name: sig_class, dtype: int64

# %%
classifier.loc[:, 'sig_class_num'] = classifier.loc[:, 'sig_class'].map({
    'Application Security':1,
    'Operations Management':2,
    'Business Resiliency':3,
    'Asset and Information Management':4,
    'Server Security':5,
    'Physical and Environment':6,
    'End User Device Security':7,
    'Access Control':8,
    'Network Security':9,
    'Incident Event & Communication Management':10,
    'Risk Assessment':11,
    'Security Policy':12,
    'Threat Management':13,
    'Compliance':14,
    'Human Resource Security':15,
    'Privacy':16,
    'Organizational Security':17,
})

# %%
classifier.loc[:, 'sig_class_num'].value_counts()
# Out:
# 1     215
# 2     120
# 3     105
# 4     104
# 5      96
# 6      86
# 7      76
# 8      74
# 9      66
# 10     45
# 11     43
# 12     42
# 13     38
# 14     31
# 15     28
# 16     18
# 17     10
# Name: sig_class_num, dtype: int64

# %%
classifier
# Out:
#      question_num                                           question response  \
# 0             A.1  Is there a risk assessment program that has be...      Yes
# 1           A.1.1  A risk assessment, conducted within the last 1...      Yes
# 2           A.1.2                                   Risk Governance?      Yes
# 3           A.1.3  Range of assets to include: people, processes,...      Yes
# 4           A.1.4  Range of threats to include: malicious, natura...      Yes
# 5           A.1.5                                      Risk scoping?      Yes
# 6           A.1.6                                      Risk context?      Yes
# 7           A.1.7                                Risk training plan?      Yes
# 8           A.1.8                          Risk evaluation criteria?      Yes
# 9           A.1.9           Risk scenarios? If yes, do they include:      Yes
# 10        A.1.9.1  Events and possible threats that could impact ...      Yes
# 11        A.1.9.2                                      Threat types?      Yes
# 12         A.1.10  Ownership, action plan, response plan, managem...      Yes
# 13            A.2  Is there a program to manage the treatment of ...      Yes
# 14          A.2.1  A formal process for assigning appropriate man...      Yes
# 15          A.2.2  A formal process for appropriate management kn...      Yes
# 16          A.2.3  A formal process for tracking the status of ac...      Yes
# 17          A.2.4        Controls identified for each material risk?      Yes
# 18          A.2.5  Measures for defining, monitoring, and reporti...      Yes
# 19        A.2.5.1                            Performance benchmarks?      Yes
# 20        A.2.5.2                Service Level Agreement Compliance?      Yes
# 21        A.2.5.3                                 Policy Compliance?      Yes
# 22        A.2.5.4                             Control Effectiveness?      Yes
# 23        A.2.5.5                          Vulnerability Management?      Yes
# 24            A.3  Do Subcontractors have access to Scoped System...       No
# 25            A.4              Is there a vendor management program?      Yes
# 26          A.4.1  Does the vendor management program include an ...       No
# 27        A.4.1.1  Risk rating of the issue (e.g., H/M/L, 1-5, et...       No
# 28        A.4.1.2                                 Remediation plans?       No
# 29        A.4.1.3                                  Remediation date?       No
# ...           ...                                                ...      ...
# 1167    U.1.37.15       Password change requirements at first logon?      n/a
# 1168    U.1.37.16  Stand alone authentication requirements such a...       No
# 1169    U.1.37.17                    Passwords encrypted in transit?      Yes
# 1170    U.1.37.18          Passwords encrypted or hashed in storage?      Yes
# 1171    U.1.37.19    Passwords displayed when entered into a system?       No
# 1172    U.1.37.20   User accounts associated to a unique individual?      Yes
# 1173    U.1.37.21  System lock requirements after 3-5 invalid log...       No
# 1174    U.1.37.22  Restricted administrative access to the manage...      Yes
# 1175    U.1.37.23  Disabling unneeded hypervisor services (e.g., ...      Yes
# 1176    U.1.37.24  Introspection capabilities to monitor the secu...      Yes
# 1177    U.1.37.25  Introspection capabilities to monitor the secu...      Yes
# 1178    U.1.37.26  Separate network VLANs for host operating syst...      Yes
# 1179    U.1.37.27  Guest operating systems communicate on separat...       No
# 1180    U.1.37.28  Host operating system management interface on ...      Yes
# 1181    U.1.37.29  Two factor authentication for access to the ad...      Yes
# 1182    U.1.37.30  Approval process before VMs can be created to ...      Yes
# 1183    U.1.37.31  Migration of VMs logged including source and t...      Yes
# 1184    U.1.37.32  VM's in the same host sharing the risk and dat...      Yes
# 1185    U.1.37.33  VM's in the same host sharing system sensitivi...      Yes
# 1186       U.1.38  Are Data Containers used to process or store S...      Yes
# 1187     U.1.38.1  Can clients prohibit containers from being use...       No
# 1188     U.1.38.2  Is there a Data Container (e.g. Docker) Securi...      Yes
# 1189     U.1.38.3  Security requirements implemented as part of t...      Yes
# 1190     U.1.38.4  Data Containers on the same host share share t...      Yes
# 1191     U.1.38.5  External Container images to be signed and ori...      n/a
# 1192     U.1.38.6  Containers are scanned for vulnerabilities and...      Yes
# 1193     U.1.38.7  Seccomp profiles are enabled to reduce the num...       No
# 1194     U.1.38.8               An Authorization Plug-In is enabled?       No
# 1195     U.1.38.9  Control Groups are enabled to reduce the kerne...      Yes
# 1196    U.1.38.10  Linux User Namespace Support is enabled to red...      Yes
#
#       maturity                                          misc_info  \
# 0          5.0  An enterprise risk assessment is performed ann...
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# 13         5.0  Risk ratings are assigned, documented and trac...
# 14         NaN                                     Please see A.2
# 15         NaN  Certain exceptions are documented and accepted...
# 16         NaN                                                NaN
# 17         NaN                                                NaN
# 18         NaN                                                NaN
# 19         NaN                                                NaN
# 20         NaN                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN
# 24         NaN  With the exception of third party data feeds a...
# 25         4.0                                     Please see A.3
# 26         NaN  An initital due diligence assessment is perfor...
# 27         NaN                                                NaN
# 28         NaN                                                NaN
# 29         NaN                                                NaN
# ...        ...                                                ...
# 1167       NaN                                      see U.1.37.11
# 1168       NaN                    This use case is not supported.
# 1169       NaN                                                NaN
# 1170       NaN                                                NaN
# 1171       NaN                              Passwords are masked.
# 1172       NaN                                                NaN
# 1173       NaN  System lock occurs at higher invalid login att...
# 1174       NaN                                                NaN
# 1175       NaN                                                NaN
# 1176       NaN                                                NaN
# 1177       NaN                                                NaN
# 1178       NaN                                                NaN
# 1179       NaN  FactSet's multi-tenant virtualized environment...
# 1180       NaN                                                NaN
# 1181       NaN                                                NaN
# 1182       NaN                                                NaN
# 1183       NaN                                                NaN
# 1184       NaN                                                NaN
# 1185       NaN                                                NaN
# 1186       NaN                                                NaN
# 1187       NaN                                                NaN
# 1188       NaN                                                NaN
# 1189       NaN                                                NaN
# 1190       NaN                                                NaN
# 1191       NaN                       External containers not used
# 1192       NaN                                                NaN
# 1193       NaN                                                NaN
# 1194       NaN                                                NaN
# 1195       NaN                                                NaN
# 1196       NaN                                                NaN
#
#                                                 aup_ref       iso_num  \
# 0               A.1 IT & Infrastructure Risk Governance     5.1 6.1.2
# 1     A.2 IT & Infrastructure Risk Assessment Life C...           8.2
# 2               A.1 IT & Infrastructure Risk Governance           NaN
# 3               A.1 IT & Infrastructure Risk Governance           NaN
# 4               A.1 IT & Infrastructure Risk Governance         6.1.2
# 5               A.1 IT & Infrastructure Risk Governance         6.1.2
# 6               A.1 IT & Infrastructure Risk Governance         6.1.2
# 7               A.1 IT & Infrastructure Risk Governance         6.1.2
# 8               A.1 IT & Infrastructure Risk Governance         6.1.2
# 9               A.1 IT & Infrastructure Risk Governance         6.1.2
# 10              A.1 IT & Infrastructure Risk Governance         6.1.2
# 11              A.1 IT & Infrastructure Risk Governance         6.1.2
# 12    A.2 IT & Infrastructure Risk Assessment Life C...         6.1.2
# 13    A.2 IT & Infrastructure Risk Assessment Life C...         6.1.3
# 14    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 15    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 16    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 17    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 18    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 19                                                  NaN           NaN
# 20                                                  NaN           NaN
# 21                                                  NaN           NaN
# 22                                                  NaN           NaN
# 23                                                  NaN           NaN
# 24                                                  NaN            15
# 25                   A.5 Vendor Risk Management Program           NaN
# 26                                                  NaN           NaN
# 27                   A.5 Vendor Risk Management Program           NaN
# 28                   A.5 Vendor Risk Management Program           NaN
# 29                   A.5 Vendor Risk Management Program           NaN
# ...                                                 ...           ...
# 1167                              H.1 Password Controls         9.3.1
# 1168                              H.1 Password Controls         9.3.1
# 1169                              H.1 Password Controls  9.3.1 10.1.1
# 1170                              H.1 Password Controls         9.3.1
# 1171                              H.1 Password Controls         9.3.1
# 1172                              H.1 Password Controls        9.2.1
# 1173                                                NaN        9.2.4
# 1174                   H.3 Logical Access Authorization   9.1.1 9.2.3
# 1175    V.4 Security Review of Hypervisor Configuration         9.4.1
# 1176    V.4 Security Review of Hypervisor Configuration        12.4.1
# 1177    V.4 Security Review of Hypervisor Configuration        12.4.1
# 1178    V.4 Security Review of Hypervisor Configuration        13.1.3
# 1179    V.4 Security Review of Hypervisor Configuration        13.1.3
# 1180    V.4 Security Review of Hypervisor Configuration        13.1.3
# 1181    V.4 Security Review of Hypervisor Configuration         9.1.1
# 1182    V.4 Security Review of Hypervisor Configuration        12.1.2
# 1183    V.4 Security Review of Hypervisor Configuration        12.4.1
# 1184    V.4 Security Review of Hypervisor Configuration        12.1.4
# 1185    V.4 Security Review of Hypervisor Configuration        12.1.4
# 1186                                                NaN           NaN
# 1187                                                NaN           NaN
# 1188                                                NaN           NaN
# 1189                                                NaN           NaN
# 1190                                                NaN           NaN
# 1191                                                NaN           NaN
# 1192                                                NaN           NaN
# 1193                                                NaN           NaN
# 1194                                                NaN           NaN
# 1195                                                NaN           NaN
# 1196                                                NaN           NaN
#
#                                                iso_desc        sig_class  \
# 0     Leadership & Commitment, Information Security ...  Risk Assessment
# 1                  Information security risk assessment  Risk Assessment
# 2                                                   NaN  Risk Assessment
# 3                                                   NaN  Risk Assessment
# 4                  Information Security Risk Assessment  Risk Assessment
# 5                  Information Security Risk Assessment  Risk Assessment
# 6                  Information Security Risk Assessment  Risk Assessment
# 7                  Information Security Risk Assessment  Risk Assessment
# 8                  Information Security Risk Assessment  Risk Assessment
# 9                  Information Security Risk Assessment  Risk Assessment
# 10                 Information Security Risk Assessment  Risk Assessment
# 11                 Information Security Risk Assessment  Risk Assessment
# 12                 Information Security Risk Assessment  Risk Assessment
# 13                  Information Security Risk treatment  Risk Assessment
# 14                                                  NaN  Risk Assessment
# 15                                                  NaN  Risk Assessment
# 16                                                  NaN  Risk Assessment
# 17                                                  NaN  Risk Assessment
# 18                                                  NaN  Risk Assessment
# 19                                                  NaN  Risk Assessment
# 20                                                  NaN  Risk Assessment
# 21                                                  NaN  Risk Assessment
# 22                                                  NaN  Risk Assessment
# 23                                                  NaN  Risk Assessment
# 24                               Supplier relationships  Risk Assessment
# 25                                                  NaN  Risk Assessment
# 26                                                  NaN  Risk Assessment
# 27                                                  NaN  Risk Assessment
# 28                                                  NaN  Risk Assessment
# 29                                                  NaN  Risk Assessment
# ...                                                 ...              ...
# 1167           Use of secret authentication information  Server Security
# 1168           Use of secret authentication information  Server Security
# 1169  Use of secret authentication information, Poli...  Server Security
# 1170           Use of secret authentication information  Server Security
# 1171           Use of secret authentication information  Server Security
# 1172              User registration and de-registration  Server Security
# 1173  Management of secret authentication informatio...  Server Security
# 1174  Access control policy, Management of privilege...  Server Security
# 1175                     Information access restriction  Server Security
# 1176                                      Event logging  Server Security
# 1177                                      Event logging  Server Security
# 1178                            Segregation in networks  Server Security
# 1179                            Segregation in networks  Server Security
# 1180                            Segregation in networks  Server Security
# 1181                              Access control policy  Server Security
# 1182                                  Change Management  Server Security
# 1183                                      Event logging  Server Security
# 1184  Separation of Development, Test, And Operation...  Server Security
# 1185  Separation of Development, Test, And Operation...  Server Security
# 1186                                                NaN  Server Security
# 1187                                                NaN  Server Security
# 1188                                                NaN  Server Security
# 1189                                                NaN  Server Security
# 1190                                                NaN  Server Security
# 1191                                                NaN  Server Security
# 1192                                                NaN  Server Security
# 1193                                                NaN  Server Security
# 1194                                                NaN  Server Security
# 1195                                                NaN  Server Security
# 1196                                                NaN  Server Security
#
#       sig_class_num
# 0                11
# 1                11
# 2                11
# 3                11
# 4                11
# 5                11
# 6                11
# 7                11
# 8                11
# 9                11
# 10               11
# 11               11
# 12               11
# 13               11
# 14               11
# 15               11
# 16               11
# 17               11
# 18               11
# 19               11
# 20               11
# 21               11
# 22               11
# 23               11
# 24               11
# 25               11
# 26               11
# 27               11
# 28               11
# 29               11
# ...             ...
# 1167              5
# 1168              5
# 1169              5
# 1170              5
# 1171              5
# 1172              5
# 1173              5
# 1174              5
# 1175              5
# 1176              5
# 1177              5
# 1178              5
# 1179              5
# 1180              5
# 1181              5
# 1182              5
# 1183              5
# 1184              5
# 1185              5
# 1186              5
# 1187              5
# 1188              5
# 1189              5
# 1190              5
# 1191              5
# 1192              5
# 1193              5
# 1194              5
# 1195              5
# 1196              5
#
# [1197 rows x 10 columns]

# %%
#replace NaN Values

classifier.loc[:, 'misc_info'].fillna('', inplace=True)
classifier.loc[:, 'iso_desc'].fillna('', inplace=True)
classifier.loc[:, 'aup_ref'].fillna('', inplace=True)

# %%
# combining multiple columns to create master text


classifier.loc[:, 'textfield']   = (classifier.loc[:, 'question'] + ' ' 
                                    + classifier.loc[:, 'misc_info'] + ' ' 
                                    + classifier.loc[:, 'iso_desc'] + ' ' 
                                    + classifier.loc[:, 'aup_ref'])

# %%
X = classifier.loc[:, 'textfield']
y = classifier.loc[:, 'sig_class_num']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# # EDA on Question Text

# %%
vect = CountVectorizer()
vect.fit(X_train)
X_train_dtm = vect.transform(X_train)

# %%
X_train_dtm
# Out:
# <897x2082 sparse matrix of type '<class 'numpy.int64'>'
# 	with 15481 stored elements in Compressed Sparse Row format>

# %%
X_train_dtm.todense().shape
# Out:
# (897, 2082)

# %%
X_train_dtm.todense().sum(axis=0)
# Out:
# matrix([[11,  1, 19, ...,  4,  2,  3]], dtype=int64)

# %%
vect.get_feature_names()
# Out:
# ['10',
#  '1000s',
#  '11',
#  '12',
#  '120',
#  '140',
#  '15',
#  '16',
#  '18',
#  '180',
#  '19',
#  '1x',
#  '2048',
#  '21',
#  '24',
#  '24x7',
#  '24x7x365',
#  '25',
#  '27001',
#  '2731',
#  '2fa',
#  '30',
#  '33',
#  '3402',
#  '35',
#  '365',
#  '37',
#  '3rd',
#  '40',
#  '443',
#  '60',
#  '6671',
#  '80',
#  '800',
#  '802',
#  '88',
#  '90',
#  'ability',
#  'able',
#  'about',
#  'above',
#  'abuse',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'access',
#  'accessed',
#  'accessible',
#  'accessing',
#  'accesssed',
#  'accidental',
#  'accordance',
#  'according',
#  'account',
#  'accounting',
#  'accounts',
#  'accuracy',
#  'acknowledge',
#  'acquisition',
#  'acted',
#  'action',
#  'actioned',
#  'actions',
#  'activate',
#  'activating',
#  'active',
#  'actively',
#  'activex',
#  'activities',
#  'activity',
#  'ad',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'addressed',
#  'addresses',
#  'addressing',
#  'adequacy',
#  'adjustment',
#  'admin',
#  'administration',
#  'administrative',
#  'administrator',
#  'administrators',
#  'adopted',
#  'advertising',
#  'advises',
#  'affect',
#  'affected',
#  'after',
#  'against',
#  'agencies',
#  'agents',
#  'agile',
#  'agreed',
#  'agreement',
#  'agreements',
#  'ajax',
#  'alarm',
#  'alarmed',
#  'alert',
#  'alerting',
#  'alerts',
#  'alignment',
#  'all',
#  'allocated',
#  'allow',
#  'allowed',
#  'allows',
#  'alone',
#  'along',
#  'also',
#  'altered',
#  'alternate',
#  'always',
#  'amend',
#  'among',
#  'an',
#  'analysis',
#  'analytical',
#  'analyze',
#  'analyzed',
#  'and',
#  'android',
#  'anlaysis',
#  'annual',
#  'annually',
#  'another',
#  'anti',
#  'antivirus',
#  'any',
#  'anytime',
#  'api',
#  'apis',
#  'applets',
#  'applicable',
#  'application',
#  'applications',
#  'applied',
#  'apply',
#  'approach',
#  'approaches',
#  'appropriate',
#  'appropriately',
#  'approval',
#  'approvals',
#  'approve',
#  'approved',
#  'approving',
#  'apps',
#  'architectural',
#  'architecture',
#  'are',
#  'area',
#  'areas',
#  'arising',
#  'arrangement',
#  'as',
#  'aside',
#  'aspx',
#  'assembling',
#  'assess',
#  'assessee',
#  'assessees',
#  'assessing',
#  'assessment',
#  'assessments',
#  'asset',
#  'assets',
#  'assigned',
#  'assigning',
#  'assignments',
#  'assistance',
#  'associate',
#  'associated',
#  'associations',
#  'assurance',
#  'assure',
#  'asymmetric',
#  'at',
#  'attack',
#  'attacks',
#  'attainment',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attendance',
#  'attributes',
#  'audit',
#  'auditing',
#  'auditors',
#  'audits',
#  'auth',
#  'authenticated',
#  'authentication',
#  'author',
#  'authorities',
#  'authority',
#  'authorization',
#  'authorized',
#  'automated',
#  'automatic',
#  'availability',
#  'available',
#  'avaya',
#  'avoid',
#  'awareness',
#  'aws',
#  'azure',
#  'back',
#  'background',
#  'backup',
#  'backups',
#  'badges',
#  'banners',
#  'base',
#  'based',
#  'baseline',
#  'basis',
#  'batch',
#  'batteries',
#  'battery',
#  'bcms',
#  'bcp',
#  'be',
#  'been',
#  'before',
#  'behalf',
#  'being',
#  'below',
#  'benchmark',
#  'benchmarks',
#  'best',
#  'between',
#  'binaries',
#  'binary',
#  'bins',
#  'biometric',
#  'biometrics',
#  'bit',
#  'biweekly',
#  'black',
#  'blacklist',
#  'blacklisted',
#  'block',
#  'blocking',
#  'board',
#  'boarding',
#  'boards',
#  'both',
#  'bottlenecks',
#  'bouncycastle',
#  'boundary',
#  'box',
#  'breach',
#  'bribery',
#  'bridged',
#  'bring',
#  'browswer',
#  'bugs',
#  'build',
#  'building',
#  'buildings',
#  'built',
#  'business',
#  'but',
#  'by',
#  'byod',
#  'byon',
#  'cabinet',
#  'cable',
#  'calculated',
#  'calculation',
#  'call',
#  'called',
#  'calls',
#  'cameras',
#  'can',
#  'cannot',
#  'capabilities',
#  'capability',
#  'capacity',
#  'capturing',
#  'card',
#  'cards',
#  'case',
#  'cases',
#  'cause',
#  'ccna',
#  'ccnp',
#  'cctv',
#  'cd',
#  'cds',
#  'ceh',
#  'ceiling',
#  'cell',
#  'center',
#  'centers',
#  'central',
#  'centrally',
#  'certain',
#  'certificate',
#  'certificates',
#  'certification',
#  'certifications',
#  'chain',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channels',
#  'characters',
#  'chat',
#  'checked',
#  'checking',
#  'checks',
#  'cilent',
#  'cipher',
#  'circumstances',
#  'cis',
#  'cissp',
#  'citrix',
#  'cl',
#  'class',
#  'classes',
#  'classification',
#  'classified',
#  'classify',
#  'clean',
#  'clearly',
#  'client',
#  'clients',
#  'clock',
#  'closed',
#  'cloud',
#  'co',
#  'cobit',
#  'code',
#  'codeofbusinessconductandethics',
#  'collect',
#  'collected',
#  'collection',
#  'com',
#  'command',
#  'commensurate',
#  'commit',
#  'commitment',
#  'committee',
#  'common',
#  'communicated',
#  'communication',
#  'communications',
#  'community',
#  'company',
#  'compass',
#  'compensating',
#  'competence',
#  'competencies',
#  'complaints',
#  'complete',
#  'complex',
#  'complexity',
#  'compliance',
#  'components',
#  'comprehensive',
#  'compromise',
#  'computer',
#  'computers',
#  'computing',
#  'comunicated',
#  'concerns',
#  'condition',
#  'conditions',
#  'conduct',
#  'conducted',
#  'conducting',
#  'confidential',
#  'confidentiality',
#  'configuration',
#  'configured',
#  'confirm',
#  'connect',
#  'connected',
#  'connecting',
#  'connection',
#  'connections',
#  'consequences',
#  'considered',
#  'consistency',
#  'consistent',
#  'consists',
#  'consoles',
#  'constituent',
#  'constituents',
#  'consume',
#  'contact',
#  'contacts',
#  'contain',
#  'contained',
#  'container',
#  'containers',
#  'containing',
#  'containment',
#  'contains',
#  'content',
#  'continuity',
#  'continuous',
#  'continuously',
#  'contract',
#  'contractors',
#  'contracts',
#  'contractual',
#  'control',
#  'controlcenter',
#  'controled',
#  'controlled',
#  'controls',
#  'conversations',
#  'coordinated',
#  'coordinators',
#  'cope',
#  'copied',
#  'copies',
#  'copying',
#  'core',
#  'corporate',
#  'correct',
#  'corrected',
#  'correction',
#  'corrective',
#  'corruption',
#  'cots',
#  'could',
#  'countries',
#  'cover',
#  'covered',
#  'covering',
#  'cracking',
#  'crawl',
#  'create',
#  'created',
#  'creation',
#  'credential',
#  'credentials',
#  'credit',
#  'criteria',
#  'critical',
#  'criticality',
#  'cross',
#  'cryptographic',
#  'cryptography',
#  'ctp',
#  'current',
#  'curriculum',
#  'custody',
#  'custom',
#  'customer',
#  'customers',
#  'customized',
#  'cwe',
#  'cy18',
#  'cyber',
#  'cycle',
#  'cycles',
#  'daily',
#  'dashboard',
#  'dast',
#  'data',
#  'database',
#  'databases',
#  'datacaenters',
#  'datacenter',
#  'datacenters',
#  'datasets',
#  'datastores',
#  'date',
#  'day',
#  'days',
#  'dban',
#  'de',
#  'dealing',
#  'dealt',
#  'declaring',
#  'dedicated',
#  'deemed',
#  'default',
#  'defaults',
#  'defects',
#  'define',
#  'defined',
#  'defining',
#  'definitions',
#  'delete',
#  'deleted',
#  'deletion',
#  'deliberate',
#  'delivered',
#  'delivers',
#  'delivery',
#  'denial',
#  'deny',
#  'department',
#  'departments',
#  'depending',
#  'depends',
#  'deployed',
#  'deploying',
#  'deployment',
#  'depth',
#  'derived',
#  'describe',
#  'design',
#  'designated',
#  'designates',
#  'designed',
#  'desired',
#  'desk',
#  'desktop',
#  'desktops',
#  'destroyed',
#  'destruction',
#  'detail',
#  'details',
#  'detect',
#  'detected',
#  'detection',
#  'detective',
#  'determination',
#  'determinations',
#  'determine',
#  'determined',
#  'determining',
#  'dev',
#  'develop',
#  'developed',
#  'developers',
#  'development',
#  'device',
#  'devices',
#  'diagnosis',
#  'diagnostic',
#  'did',
#  'different',
#  'digitally',
#  'diligence',
#  'direct',
#  'directly',
#  'directors',
#  'directory',
#  'disable',
#  'disabled',
#  'disabling',
#  'disallowed',
#  'disaster',
#  'disciplinary',
#  'disclose',
#  'disclosure',
#  'disclosures',
#  'disconnected',
#  'discovered',
#  'discrepancies',
#  'discuss',
#  'disease',
#  'disk',
#  'displayed',
#  'displays',
#  'disposal',
#  'dispose',
#  'disruption',
#  'disruptions',
#  'disruptive',
#  'distinguishes',
#  'distributed',
#  'diverse',
#  'divided',
#  'dlt',
#  'dmz',
#  'do',
#  'doc_downloads',
#  'dock',
#  'docker',
#  'document',
#  'documentation',
#  'documented',
#  'documents',
#  'does',
#  'doors',
#  'dos',
#  'downtime',
#  'drive',
#  'drives',
#  'dsl',
#  'due',
#  'during',
#  'duties',
#  'dvd',
#  'dvds',
#  'dynamic',
#  'each',
#  'eap',
#  'ecosystem',
#  'edge',
#  'education',
#  'effective',
#  'effectiveness',
#  'effort',
#  'efforts',
#  'eight',
#  'either',
#  'electronic',
#  'electronically',
#  'elements',
#  'eliminated',
#  'email',
#  'emails',
#  'emergency',
#  'employed',
#  'employee',
#  'employees',
#  'employment',
#  'employs',
#  'enable',
#  'enabled',
#  'enabling',
#  'encourages',
#  'encrypt',
#  'encrypted',
#  'encrypting',
#  'encryption',
#  'end',
#  'endpoint',
#  'enforce',
#  'enforced',
#  'enforcement',
#  'enforces',
#  'engaged',
#  'engages',
#  'engine',
#  'engineering',
#  'engineers',
#  'engines',
#  'enhance',
#  'ensure',
#  'ensures',
#  'ensuring',
#  'entered',
#  'enterpise',
#  'enterprise',
#  'entire',
#  'entitled',
#  'entitlement',
#  'entitlements',
#  'entity',
#  'entry',
#  'enviornments',
#  'environment',
#  'environmental',
#  'environments',
#  'equipment',
#  'equipped',
#  'eradication',
#  'erased',
#  'error',
#  'errors',
#  'escalate',
#  'escalated',
#  'escalation',
#  'escorted',
#  'essential',
#  'establish',
#  'established',
#  'establishing',
#  'establishment',
#  'etc',
#  'ethical',
#  'ethics',
#  'evaluate',
#  'evaluated',
#  'evaluation',
#  'event',
#  'events',
#  'ever',
#  'every',
#  'evidence',
#  'exception',
#  'exceptions',
#  'exchange',
#  'excluded',
#  'exclusions',
#  'executables',
#  'execute',
#  'executed',
#  'executing',
#  'execution',
#  'executive',
#  'exercise',
#  'exercises',
#  'exercising',
#  'exist',
#  'existing',
#  'exit',
#  'exits',
#  'expectations',
#  'expedited',
#  'expedites',
#  'experienced',
#  'expertise',
#  'experts',
#  'expiration',
#  'explain',
#  'exploitation',
#  'exploits',
#  'exposure',
#  'extend',
#  'extending',
#  'extensive',
#  'exterior',
#  'external',
#  'externally',
#  'extraction',
#  'extranet',
#  'facilities',
#  'facility',
#  'facing',
#  'factor',
#  'factors',
#  'factset',
#  'failed',
#  'failover',
#  'fails',
#  'failure',
#  'failures',
#  'fall',
#  'false',
#  'feature',
#  'features',
#  'fed',
#  'feedback',
#  'feeds',
#  'fields',
#  'file',
#  'files',
#  'filter',
#  'financial',
#  'findings',
#  'finished',
#  'fips',
#  'fire',
#  'firewall',
#  'firewalls',
#  'firm',
#  'first',
#  'five',
#  'fixes',
#  'floor',
#  'floppy',
#  'flows',
#  'fob',
#  'focused',
#  'folders',
#  'follow',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'forced',
#  'forensic',
#  'form',
#  'formal',
#  'formally',
#  'forums',
#  'found',
#  'four',
#  'framework',
#  'frameworks',
#  'fraud',
#  'freeware',
#  'frequency',
#  'from',
#  'fuel',
#  'full',
#  'fully',
#  'function',
#  'functional',
#  'functionality',
#  'functioning',
#  'functions',
#  'funding',
#  'fuzz',
#  'fuzzing',
#  'gain',
#  'gap',
#  'gateways',
#  'general',
#  'generally',
#  'generate',
#  'generated',
#  'generates',
#  'generation',
#  'generator',
#  'generators',
#  'get',
#  'given',
#  'glass',
#  'global',
#  'go',
#  'goals',
#  'google',
#  'govdoc',
#  'govern',
#  'governance',
#  'government',
#  'granting',
#  'granular',
#  'green',
#  'group',
#  'grouping',
#  'groups',
#  'guard',
#  'guards',
#  'guest',
#  'guided',
#  'guideline',
#  'guidelines',
#  'hacking',
#  'handheld',
#  'handled',
#  'handling',
#  'happens',
#  'hard',
#  'hardened',
#  'hardening',
#  'hardware',
#  'has',
#  'hashed',
#  'have',
#  'health',
#  'heat',
#  'help',
#  'here',
#  'high',
#  'higher',
#  'highly',
#  'hinge',
#  'hipaa',
#  'hire',
#  'history',
#  'hitech',
#  'hoc',
#  'hold',
#  'holdings',
#  'host',
#  'hosted',
#  'hosting',
#  'hosts',
#  'hot',
#  'hotspots',
#  'hour',
#  'hours',
#  'house',
#  'how',
#  'however',
#  'hr',
#  'hsm',
#  'http',
#  'https',
#  'human',
#  'humidity',
#  'hvac',
#  'hybrid',
#  'hydrogen',
#  'hypervisor',
#  'hypervisors',
#  'iaas',
#  'ica',
#  'id',
#  'identifiable',
#  'identification',
#  'identified',
#  'identifies',
#  'identify',
#  'identifying',
#  'identity',
#  'idle',
#  'ids',
#  'if',
#  'image',
#  'images',
#  'immediately',
#  'impact',
#  'impacted',
#  'impacting',
#  'implement',
#  'implementation',
#  'implemented',
#  'implementing',
#  'importance',
#  'improvement',
#  'improvements',
#  'in',
#  'inaccurate',
#  'inactive',
#  'inactivity',
#  'inadvertent',
#  'inappropriate',
#  'inbound',
#  'incident',
#  'incidents',
#  'include',
#  'included',
#  'includes',
#  'including',
#  'incomplete',
#  'incorporate',
#  'independent',
#  'independently',
#  'indicate',
#  'indication',
#  'individual',
#  'individuals',
#  'industry',
#  'infections',
#  'infectious',
#  'influenza',
#  'info',
#  'information',
#  'infrastructure',
#  'initial',
#  'initially',
#  'initiate',
#  'initital',
#  'injection',
#  'injections',
#  'input',
#  'inputs',
#  'insert',
#  'inside',
#  'insider',
#  'inspect',
#  'inspection',
#  'installation',
#  'installed',
#  'installing',
#  'instance',
#  'instances',
#  'instantiated',
#  'insure',
#  'integrated',
#  'integration',
#  'integrity',
#  'intellectual',
#  'intelligent',
#  'intended',
#  'interact',
#  'interacting',
#  'interaction',
#  'interactions',
#  'interactive',
#  'intercepted',
#  'interest',
#  'interested',
#  'interface',
#  'interfaces',
#  'internal',
#  'internally',
#  'internet',
#  'interruptions',
#  'interval',
#  'intervals',
#  'intervention',
#  'into',
#  'intranet',
#  'introduction',
#  'introspection',
#  'intrusion',
#  'invalid',
#  'inventoried',
#  'inventory',
#  'investigate',
#  'investigates',
#  'investigating',
#  'investigation',
#  'investor',
#  'investors',
#  'invoke',
#  'invoked',
#  'involve',
#  'involved',
#  'involving',
#  'ios',
#  'ip',
#  'ips',
#  'iron',
#  'is',
#  'isae',
#  'iso',
#  'isolate',
#  ...]

# %%
vect.vocabulary_
# Out:
# {'are': 155,
#  'apis': 136,
#  'tested': 1862,
#  'for': 767,
#  'security': 1659,
#  'weaknesses': 2030,
#  'if': 888,
#  'yes': 2076,
#  'does': 588,
#  'this': 1875,
#  'include': 911,
#  'management': 1113,
#  'of': 1229,
#  'technical': 1843,
#  'vulnerabilities': 2022,
#  'is': 996,
#  'scoped': 1644,
#  'systems': 1825,
#  'and': 125,
#  'data': 470,
#  'ever': 684,
#  'used': 1976,
#  'in': 902,
#  'the': 1867,
#  'test': 1861,
#  'development': 539,
#  'or': 1262,
#  'qa': 1472,
#  'environments': 660,
#  'protection': 1452,
#  'software': 1739,
#  'program': 1436,
#  'bouncycastle': 254,
#  'openssl': 1248,
#  'prior': 1411,
#  'to': 1893,
#  'device': 540,
#  'on': 1240,
#  'boarding': 250,
#  'constituents': 396,
#  'required': 1565,
#  'sign': 1712,
#  'legal': 1045,
#  'agreement': 98,
#  'which': 2040,
#  'details': 525,
#  'obligations': 1224,
#  'rights': 1606,
#  'related': 1527,
#  'mobile': 1159,
#  'devices': 541,
#  'it': 1006,
#  'policy': 1378,
#  'errors': 666,
#  'resulting': 1588,
#  'from': 781,
#  'incomplete': 915,
#  'inaccurate': 903,
#  'business': 267,
#  'reporting': 1556,
#  'information': 928,
#  'events': 683,
#  'technology': 1847,
#  'incident': 909,
#  'detection': 528,
#  'there': 1871,
#  'formal': 771,
#  'methodology': 1146,
#  'operation': 1252,
#  'groups': 820,
#  'agile': 96,
#  'programming': 1437,
#  'control': 415,
#  'operational': 1253,
#  '16': 7,
#  'secure': 1655,
#  'lifecycle': 1062,
#  'sdlc': 1653,
#  'reviews': 1601,
#  'real': 1493,
#  'time': 1884,
#  'alerting': 104,
#  'event': 682,
#  'logging': 1083,
#  'monitoring': 1175,
#  'review': 1599,
#  'supplier': 1807,
#  'services': 1686,
#  'remote': 1542,
#  'access': 47,
#  'administrative': 84,
#  'interfaces': 965,
#  'configured': 382,
#  'require': 1564,
#  'authentication': 197,
#  'encryption': 631,
#  'networks': 1199,
#  'network': 1197,
#  'restrictions': 1586,
#  'multifactor': 1186,
#  'potential': 1391,
#  'impact': 892,
#  'change': 309,
#  'code': 340,
#  'analysis': 121,
#  'performed': 1333,
#  'by': 269,
#  'qualified': 1474,
#  'personnel': 1349,
#  'other': 1271,
#  'than': 1865,
#  'author': 198,
#  'relevant': 1533,
#  'introduction': 975,
#  'production': 1430,
#  'environment': 658,
#  'system': 1824,
#  'procedures': 1424,
#  'staff': 1763,
#  'dedicated': 486,
#  'compliance': 365,
#  'risk': 1607,
#  'responsibilities': 1578,
#  'user': 1977,
#  'revoked': 1603,
#  'within': 2057,
#  '24': 14,
#  'hours': 861,
#  'termination': 1858,
#  'so': 1737,
#  'please': 1371,
#  'describe': 513,
#  'see': 1660,
#  '11': 2,
#  'hypervisor': 874,
#  'configuration': 381,
#  'service': 1685,
#  'provider': 1457,
#  'provided': 1456,
#  'house': 862,
#  'factset': 729,
#  'password': 1313,
#  'requirements': 1567,
#  'at': 182,
#  'first': 754,
#  'logon': 1088,
#  '37': 26,
#  'use': 1975,
#  'secret': 1654,
#  'controls': 419,
#  'email': 616,
#  'manage': 1111,
#  'treatment': 1923,
#  'risks': 1608,
#  'identified': 881,
#  'during': 596,
#  'assessments': 169,
#  'ratings': 1486,
#  'assigned': 172,
#  'documented': 586,
#  'tracked': 1902,
#  'via': 2000,
#  'custom': 458,
#  'portal': 1381,
#  'as': 160,
#  'part': 1305,
#  'assurance': 179,
#  'processes': 1427,
#  'infrastructure': 929,
#  'assessment': 168,
#  'life': 1061,
#  'cycle': 465,
#  'community': 355,
#  'cloud': 337,
#  'deployment': 510,
#  'models': 1163,
#  'agreed': 97,
#  'set': 1690,
#  'audits': 194,
#  'ensure': 645,
#  'with': 2056,
#  'applicable': 138,
#  'regulatory': 1526,
#  'industry': 923,
#  'has': 836,
#  'financial': 746,
#  'audit': 191,
#  'committee': 350,
#  'whose': 2048,
#  'roles': 1610,
#  'outlined': 1280,
#  'our': 1273,
#  'corporate': 428,
#  'governance': 813,
#  'page': 1300,
#  'http': 867,
#  'investor': 985,
#  'com': 345,
#  'investors': 986,
#  'default': 488,
#  'aspx': 162,
#  'operating': 1251,
#  'application': 139,
#  'logs': 1089,
#  'supporting': 1813,
#  'investigation': 984,
#  'protected': 1450,
#  'against': 93,
#  'modification': 1165,
#  'deletion': 497,
#  'inappropriate': 907,
#  'common': 351,
#  'bugs': 262,
#  'that': 1866,
#  'need': 1194,
#  'be': 227,
#  'eliminated': 615,
#  'identification': 880,
#  'recovery': 1511,
#  'continuity': 408,
#  'monitor': 1173,
#  'privacy': 1416,
#  'incidents': 910,
#  'independent': 917,
#  'communication': 353,
#  'changes': 311,
#  'all': 107,
#  'periodic': 1338,
#  'least': 1039,
#  'annual': 128,
#  'your': 2078,
#  'resiliency': 1573,
#  'establish': 672,
#  'implement': 895,
#  'exercising': 700,
#  'files': 744,
#  'stored': 1782,
#  'different': 545,
#  'file': 743,
#  'vulnerability': 2023,
#  'scanning': 1635,
#  'range': 1482,
#  'assets': 171,
#  'people': 1329,
#  'daily': 467,
#  'approval': 147,
#  'connect': 384,
#  'company': 356,
#  'connected': 385,
#  'endpoint': 633,
#  'server': 1682,
#  'workstation': 2067,
#  'wireless': 2055,
#  'point': 1375,
#  'another': 130,
#  'modem': 1164,
#  'line': 1067,
#  'cable': 273,
#  'dsl': 594,
#  'phone': 1354,
#  'internet': 968,
#  'non': 1206,
#  'authorized': 202,
#  'traffic': 1904,
#  'do': 580,
#  'deny': 503,
#  'temporary': 1850,
#  'workers': 2060,
#  'responsible': 1580,
#  'performing': 1334,
#  'entitlement': 653,
#  'subcontractors': 1796,
#  'no': 1204,
#  'explain': 712,
#  'third': 1874,
#  'parties': 1307,
#  'not': 1208,
#  'have': 838,
#  'cilent': 319,
#  'addressing': 79,
#  'agreements': 99,
#  'customer': 459,
#  'scored': 1647,
#  'awareness': 209,
#  'training': 1907,
#  'policies': 1377,
#  'standards': 1770,
#  'physically': 1357,
#  'tls': 1892,
#  'encrypting': 630,
#  'web': 2031,
#  'pages': 1301,
#  'applications': 140,
#  'included': 912,
#  'penetration': 1328,
#  'tests': 1864,
#  'developed': 537,
#  'they': 1873,
#  'activity': 71,
#  'level': 1052,
#  'planning': 1367,
#  'exterior': 719,
#  'doors': 589,
#  'external': 720,
#  'hinge': 846,
#  'pins': 1362,
#  'physical': 1356,
#  'perimeter': 1336,
#  'remediation': 1541,
#  'findings': 747,
#  'acceptance': 44,
#  'testing': 1863,
#  'process': 1425,
#  'prevent': 1402,
#  'unauthorized': 1942,
#  'connecting': 386,
#  'internal': 966,
#  'detect': 526,
#  'alert': 103,
#  'an': 120,
#  'administrator': 85,
#  'lan': 1025,
#  'connections': 388,
#  'public': 1465,
#  'areas': 157,
#  'disconnected': 561,
#  'extranet': 723,
#  'etc': 676,
#  'owner': 1295,
#  'scoping': 1645,
#  'architecture': 154,
#  'when': 2036,
#  'new': 1200,
#  'platforms': 1370,
#  'designed': 517,
#  'specification': 1751,
#  'architectural': 153,
#  'design': 514,
#  'storage': 1780,
#  'equipment': 661,
#  'off': 1230,
#  'premise': 1395,
#  'asset': 170,
#  'accounting': 56,
#  'inventory': 980,
#  'been': 228,
#  'approved': 150,
#  'communicated': 352,
#  'appropriate': 145,
#  'constituent': 395,
#  'maintain': 1101,
#  'checking': 317,
#  'established': 673,
#  'exercise': 698,
#  'scenario': 1637,
#  'cyber': 464,
#  'resilience': 1572,
#  'team': 1841,
#  'invoked': 988,
#  'portions': 1383,
#  'response': 1577,
#  'plan': 1365,
#  'address': 76,
#  'routine': 1618,
#  'exploits': 714,
#  'wannacry': 2027,
#  'expedited': 706,
#  'patching': 1318,
#  'regiment': 1519,
#  'generated': 799,
#  'alerts': 105,
#  'log': 1081,
#  'failure': 733,
#  'sufficient': 1804,
#  'detail': 524,
#  'contained': 401,
#  'support': 1811,
#  'including': 914,
#  'successful': 1801,
#  'failed': 730,
#  'login': 1086,
#  'attempts': 188,
#  'sensitive': 1673,
#  'settings': 1692,
#  'objective': 1221,
#  'essential': 671,
#  'timestaps': 1890,
#  'ip': 993,
#  'info': 927,
#  'rulesets': 1620,
#  'disabling': 554,
#  'auditing': 192,
#  'view': 2002,
#  'uptime': 1971,
#  'portfolio': 1382,
#  'presents': 1401,
#  'transparent': 1920,
#  'dashboard': 468,
#  'center': 299,
#  'shows': 1706,
#  'status': 1777,
#  'critical': 449,
#  'batch': 222,
#  'runs': 1623,
#  'state': 1773,
#  'reconciliation': 1506,
#  'round': 1616,
#  'clock': 335,
#  'workflow': 2061,
#  'coordinators': 422,
#  'specialists': 1748,
#  'only': 1245,
#  'integrity': 952,
#  'but': 268,
#  'also': 114,
#  'quality': 1475,
#  'work': 2059,
#  'independently': 918,
#  'client': 333,
#  'remediate': 1539,
#  'timing': 1891,
#  'integrated': 950,
#  'raw': 1487,
#  'derived': 512,
#  'calculated': 274,
#  'issues': 1004,
#  'updates': 1963,
#  'maximum': 1126,
#  'acceptable': 43,
#  'outage': 1275,
#  'tolerable': 1896,
#  'period': 1337,
#  'disruption': 571,
#  'each': 601,
#  'threat': 1879,
#  'types': 1936,
#  'create': 442,
#  'lists': 1069,
#  'clients': 334,
#  'can': 280,
#  'define': 491,
#  'source': 1743,
#  'whitelists': 2045,
#  'sftp': 1694,
#  'privileged': 1419,
#  'identify': 883,
#  'any': 133,
#  'legacy': 1044,
#  'accessing': 50,
#  'loading': 1072,
#  'dock': 582,
#  'facility': 725,
#  'delivery': 501,
#  'firewall': 751,
#  'waf': 2025,
#  'enabled': 625,
#  'handling': 830,
#  '33': 22,
#  'clean': 331,
#  'desk': 519,
#  'minimizes': 1150,
#  'paper': 1303,
#  'records': 1509,
#  'relying': 1537,
#  'electronic': 612,
#  'however': 864,
#  'printers': 1410,
#  'checked': 316,
#  'nightly': 1202,
#  'leftover': 1043,
#  'papers': 1304,
#  'whiteboard': 2043,
#  'notes': 1209,
#  'erased': 664,
#  'destroyed': 522,
#  'trains': 1908,
#  'employees': 621,
#  'securely': 1657,
#  'store': 1781,
#  'confidential': 379,
#  'documents': 587,
#  'dispose': 570,
#  'them': 1870,
#  'shred': 1707,
#  'bins': 239,
#  'document': 584,
#  'longer': 1091,
#  'serves': 1684,
#  'keep': 1015,
#  'record': 1507,
#  'passwords': 1314,
#  'handheld': 828,
#  'encrypted': 629,
#  'hashed': 837,
#  'contractors': 412,
#  '12': 3,
#  'subcontractor': 1795,
#  'container': 402,
#  'docker': 583,
#  'installation': 943,
#  'externally': 721,
#  'reuse': 1597,
#  'media': 1137,
#  'tapes': 1837,
#  'disk': 566,
#  'drives': 593,
#  'disposal': 569,
#  're': 1489,
#  'customers': 460,
#  'notification': 1211,
#  'escalation': 669,
#  'protocols': 1454,
#  'warning': 2028,
#  'lock': 1076,
#  'account': 55,
#  'three': 1881,
#  'five': 755,
#  'invalid': 978,
#  'made': 1098,
#  'inactive': 904,
#  'accounts': 57,
#  'transit': 1914,
#  'cryptographic': 452,
#  'rest': 1581,
#  'personal': 1347,
#  'collected': 343,
#  'directly': 549,
#  'individuals': 922,
#  'minimum': 1151,
#  'length': 1048,
#  'eight': 610,
#  'characters': 314,
#  'place': 1363,
#  'enforces': 637,
#  'complexity': 364,
#  'expiration': 711,
#  'follows': 766,
#  'standard': 1769,
#  'best': 235,
#  'practices': 1393,
#  'disclose': 558,
#  'additional': 74,
#  'inventoried': 979,
#  'quarterly': 1477,
#  'destruction': 523,
#  'reviewed': 1600,
#  'last': 1028,
#  'months': 1178,
#  'did': 544,
#  'content': 407,
#  'ability': 37,
#  'generate': 798,
#  'unique': 1952,
#  'key': 1018,
#  'generates': 800,
#  'keys': 1019,
#  'logoff': 1087,
#  'terminals': 1854,
#  'pc': 1323,
#  'servers': 1683,
#  'session': 1688,
#  'finished': 748,
#  'unattended': 1941,
#  'weekly': 2033,
#  'anti': 131,
#  'malware': 1110,
#  'version': 1998,
#  'engine': 640,
#  'upgrade': 1964,
#  'failures': 734,
#  'return': 1595,
#  'computers': 370,
#  'cell': 298,
#  'phones': 1355,
#  'cards': 287,
#  'tokens': 1895,
#  'smart': 1731,
#  'influenza': 926,
#  'pandemic': 1302,
#  'infectious': 925,
#  'disease': 565,
#  'outbreak': 1278,
#  'normal': 1207,
#  'bcp': 226,
#  'would': 2070,
#  'cover': 437,
#  'situation': 1728,
#  'instance': 946,
#  'remotely': 1543,
#  'location': 1074,
#  'through': 1882,
#  'vpn': 2021,
#  'tunnels': 1931,
#  'able': 38,
#  'unencrypted': 1950,
#  'sales': 1627,
#  'developers': 538,
#  'engineers': 642,
#  'admin': 82,
#  'virtualized': 2009,
#  'persistent': 1345,
#  'limited': 1066,
#  'sandbox': 1630,
#  'well': 2034,
#  'monitored': 1174,
#  'logged': 1082,
#  'specify': 1753,
#  'case': 288,
#  'request': 1561,
#  'may': 1127,
#  'subscribe': 1799,
#  'receive': 1499,
#  'timely': 1885,
#  'copies': 425,
#  'containing': 404,
#  'stated': 1774,
#  'cases': 289,
#  'actions': 64,
#  'being': 231,
#  'tagged': 1829,
#  'violates': 2004,
#  'who': 2047,
#  'immediately': 891,
#  'investigates': 982,
#  'enterpise': 649,
#  'hosting': 856,
#  'enviornments': 657,
#  'single': 1724,
#  'tenant': 1852,
#  'designates': 516,
#  'specific': 1749,
#  'administrators': 86,
#  'pods': 1374,
#  'based': 219,
#  'employee': 620,
#  'role': 1609,
#  'segregation': 1665,
#  'duties': 597,
#  'additionally': 75,
#  'allowed': 110,
#  'whitelisted': 2044,
#  'hosts': 857,
#  'restriction': 1585,
#  'logical': 1084,
#  'authorization': 201,
#  'regularly': 1524,
#  'using': 1980,
#  'uncover': 1946,
#  'follow': 763,
#  'guidelines': 826,
#  'owasp': 1292,
#  '30': 21,
#  'min': 1149,
#  'biometrics': 241,
#  'ups': 1970,
#  'maintenance': 1105,
#  'environmental': 659,
#  'computing': 371,
#  'hardware': 835,
#  'owned': 1294,
#  'byod': 270,
#  'assessee': 165,
#  'un': 1940,
#  'managed': 1112,
#  'transmitting': 1919,
#  'processing': 1428,
#  'storing': 1784,
#  'objectives': 1223,
#  'resources': 1576,
#  'prohibit': 1439,
#  'containers': 403,
#  'fully': 784,
#  'implemented': 897,
#  'vendor': 1992,
#  'lost': 1093,
#  'stolen': 1779,
#  'card': 286,
#  'entry': 656,
#  'mechanism': 1135,
#  'tailgating': 1831,
#  'piggybacking': 1358,
#  'prohibiting': 1441,
#  'users': 1978,
#  'sharing': 1698,
#  'insider': 940,
#  'threats': 1880,
#  'validate': 1986,
#  'twice': 1933,
#  'yearly': 2075,
#  'edge': 604,
#  'boundary': 255,
#  'value': 1989,
#  'condition': 374,
#  '10': 0,
#  'qa_uat': 1473,
#  'results': 1589,
#  'retention': 1592,
#  'track': 1901,
#  'periodically': 1339,
#  'those': 1878,
#  'annually': 129,
#  'intrusion': 977,
#  'prevention': 1405,
#  'employed': 619,
#  'zones': 2081,
#  'wherever': 2038,
#  'firewalls': 752,
#  'ids': 887,
#  'ips': 994,
#  'attributes': 190,
#  'top': 1899,
#  'cwe': 462,
#  '25': 17,
#  'continuous': 409,
#  'api': 135,
#  'permission': 1341,
#  'model': 1161,
#  'available': 206,
#  'high': 843,
#  'patches': 1317,
#  'applied': 141,
#  'verified': 1996,
#  'monthly': 1177,
#  'maintains': 1104,
#  'regular': 1523,
#  'patch': 1315,
#  'makes': 1107,
#  'deliberate': 498,
#  'determinations': 531,
#  'train': 1905,
#  'class': 326,
#  'such': 1802,
#  'evaluated': 680,
#  'released': 1531,
#  'monitors': 1176,
#  'both': 252,
#  'issued': 1003,
#  'continuously': 410,
#  'perform': 1331,
#  'levels': 1053,
#  'along': 113,
#  'compensating': 358,
#  'vulnerable': 2024,
#  'attack': 183,
#  'severity': 1693,
#  'expedites': 707,
#  'known': 1023,
#  'wild': 2049,
#  'leverages': 1056,
#  'techniques': 1845,
#  'cots': 434,
#  'vendors': 1993,
#  'kernel': 1017,
#  'splicing': 1755,
#  'allow': 109,
#  'zero': 2079,
#  'downtime': 591,
#  'manner': 1118,
#  'limit': 1065,
#  'exposure': 715,
#  'complex': 363,
#  'simultaneous': 1723,
#  'utilize': 1983,
#  'following': 765,
#  'functions': 789,
#  'controlled': 418,
#  'number': 1216,
#  'ios': 992,
#  'aside': 161,
#  'these': 1872,
#  'purpose': 1468,
#  'providing': 1460,
#  'assistance': 175,
#  'type': 1935,
#  'mdm': 1128,
#  'accessible': 49,
#  'permit': 1343,
#  'requires': 1568,
#  'installed': 944,
#  'certificates': 305,
#  'centrally': 302,
#  'kept': 1016,
#  'current': 455,
#  'fire': 750,
#  'alarm': 101,
#  'networking': 1198,
#  '802': 34,
#  '1x': 11,
#  'wpa2': 2071,
#  'enterprise': 650,
#  'eap': 602,
#  'active': 67,
#  'rotation': 1615,
#  'hardening': 834,
#  'switches': 1821,
#  'routers': 1617,
#  'points': 1376,
#  'baseline': 220,
#  'inside': 939,
#  'databases': 472,
#  'according': 54,
#  'principle': 1408,
#  'privilege': 1418,
#  'confirm': 383,
#  'removed': 1547,
#  'folders': 762,
#  'separate': 1677,
#  'drive': 592,
#  'retained': 1591,
#  'one': 1242,
#  'year': 2074,
#  'modeling': 1162,
#  'into': 973,
#  'lessons': 1050,
#  'learned': 1037,
#  'arising': 158,
#  'disruptive': 573,
#  'tablespace': 1826,
#  'establishment': 675,
#  'restart': 1582,
#  'transmit': 1916,
#  'end': 632,
#  'desktops': 521,
#  'laptops': 1026,
#  'tablets': 1827,
#  'smartphones': 1732,
#  'locations': 1075,
#  'datacenters': 475,
#  'govern': 812,
#  'copying': 426,
#  'facing': 726,
#  'violate': 2003,
#  'stand': 1768,
#  'alone': 112,
#  'pin': 1360,
#  'question': 1478,
#  'supported': 1812,
#  'biometric': 240,
#  'protect': 1449,
#  'forensic': 769,
#  'two': 1934,
#  'factor': 727,
#  'enable': 624,
#  'reasonably': 1497,
#  'amend': 118,
#  'phi': 1353,
#  'maintained': 1102,
#  'upon': 1968,
#  'party': 1312,
#  'rules': 1619,
#  'replaced': 1551,
#  'proprietary': 1448,
#  'delivers': 500,
#  'full': 783,
#  'core': 427,
#  'https': 868,
#  'controlcenter': 416,
#  'indication': 920,
#  'general': 796,
#  'reasonable': 1496,
#  'discuss': 564,
#  'we': 2029,
#  'always': 117,
#  'concerns': 373,
#  'depth': 511,
#  'conversations': 420,
#  'scans': 1636,
#  'restricted': 1584,
#  'backup': 214,
#  'replication': 1553,
#  'corrected': 430,
#  'token': 1894,
#  'fob': 760,
#  'reader': 1491,
#  'workspace': 2065,
#  'ownership': 1296,
#  'action': 62,
#  'update': 1961,
#  'interruptions': 969,
#  'impacting': 894,
#  'notify': 1214,
#  'multiple': 1187,
#  'feeds': 741,
#  'utilities': 1981,
#  'priority': 1415,
#  'cctv': 293,
#  'video': 2001,
#  '90': 36,
#  'days': 480,
#  'displayed': 567,
#  'entered': 648,
#  'masked': 1123,
#  'created': 443,
#  'either': 611,
#  'contain': 400,
#  'name': 1189,
#  'ssn': 1761,
#  'protecting': 1451,
#  'department': 504,
#  'similar': 1721,
#  'oversight': 1290,
#  'unit': 1953,
#  'responsibility': 1579,
#  'assessing': 167,
#  'identifying': 884,
#  'tracking': 1903,
#  'resolution': 1574,
#  'outstanding': 1285,
#  'ensures': 646,
#  'legislation': 1046,
#  'contractual': 414,
#  'requirement': 1566,
#  'execution': 696,
#  'scan': 1633,
#  'impacted': 893,
#  'disaster': 556,
#  'loss': 1092,
#  'reduction': 1513,
#  'repositories': 1558,
#  'implementing': 898,
#  'subnet': 1798,
#  'defined': 492,
#  'procedure': 1423,
#  'correct': 429,
#  'without': 2058,
#  'virus': 2010,
#  'feedback': 740,
#  'interested': 963,
#  'evaluation': 681,
#  'prioritize': 1413,
#  'alternate': 116,
#  'siem': 1710,
#  'compromise': 368,
#  'conducted': 377,
#  'certification': 306,
#  '3rd': 27,
#  'basis': 221,
#  'seek': 1661,
#  'operations': 1254,
#  'copied': 424,
#  '19': 10,
#  'target': 1838,
#  'publicly': 1466,
#  'distributed': 575,
#  'government': 814,
#  'recognized': 1504,
#  'authority': 200,
#  'published': 1467,
#  'cis': 322,
#  'tenancy': 1851,
#  'multi': 1185,
#  'radius': 1480,
#  'enforce': 634,
#  'central': 301,
#  'auth': 195,
#  'capabilities': 282,
#  'requiring': 1569,
#  'permissions': 1342,
#  'modify': 1168,
#  'dynamic': 600,
#  'dast': 469,
#  'segmentation': 1662,
#  'id': 878,
#  'metadata': 1144,
#  'tagging': 1830,
#  'determine': 532,
#  'whether': 2039,
#  'features': 738,
#  'effective': 606,
#  'legislative': 1047,
#  'updated': 1962,
#  'presented': 1400,
#  'trained': 1906,
#  'conduct': 376,
#  'ethics': 678,
#  'signed': 1716,
#  'biweekly': 243,
#  'library': 1058,
#  'plans': 1368,
#  'shell': 1699,
#  'ui': 1939,
#  'migration': 1148,
#  'vms': 2017,
#  'leading': 1035,
#  'exceptions': 688,
#  'mitigation': 1157,
#  'strategies': 1786,
#  'group': 818,
#  'organizational': 1267,
#  'structure': 1792,
#  'necessary': 1193,
#  'after': 92,
#  'locked': 1077,
#  'cabinet': 272,
#  'sessions': 1689,
#  'out': 1274,
#  '15': 6,
#  'minutes': 1154,
#  'less': 1049,
#  'minute': 1153,
#  ...}

# %% [markdown]
# # Train Test Classifier using Naive Bayes

# %%
#Create Document-term Matrices with CountVectorizer()
vect = CountVectorizer()
vect.fit(X_train)
X_train_dtm = vect.transform(X_train)
X_test_dtm = vect.transform(X_test)

#Use Naive Bayes to predict sig_class_num
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)

# %%
# calculate accuracy
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.62333333333333329

# %%
y_test.value_counts()
# Out:
# 1     53
# 3     36
# 2     26
# 4     26
# 5     24
# 6     22
# 7     19
# 9     18
# 8     15
# 12    11
# 15    10
# 11     9
# 14     9
# 10     8
# 13     7
# 17     4
# 16     3
# Name: sig_class_num, dtype: int64

# %%
# Define a function that accepts a vectorizer and calculates the accuracy.

def tokenize_test(vect):
    vect.fit(X_train)
    X_train_dtm = vect.transform(X_train)
    print('Number of features: ', X_train_dtm.shape[1])
    X_test_dtm = vect.transform(X_test)
    
    nb = MultinomialNB()
    nb.fit(X_train_dtm, y_train)
    y_pred_class = nb.predict(X_test_dtm)
    print('Accuracy: ', metrics.accuracy_score(y_test, y_pred_class))

# %%
vect = CountVectorizer()
tokenize_test(vect)
# Out:
# Number of features:  2082
# Accuracy:  0.623333333333

# %%
vect = CountVectorizer(ngram_range=(1,2))
tokenize_test(vect)
# Out:
# Number of features:  10439
# Accuracy:  0.626666666667

# %%
vect = CountVectorizer(stop_words='english')

vect.get_stop_words()
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
tokenize_test(vect)
# Out:
# Number of features:  1932
# Accuracy:  0.63

# %%
vect = CountVectorizer(stop_words='english')
tokenize_test(vect)
# Out:
# Number of features:  1932
# Accuracy:  0.63

# %%
vect.get_feature_names()
# Out:
# ['10',
#  '1000s',
#  '11',
#  '12',
#  '120',
#  '140',
#  '15',
#  '16',
#  '18',
#  '180',
#  '19',
#  '1x',
#  '2048',
#  '21',
#  '24',
#  '24x7',
#  '24x7x365',
#  '25',
#  '27001',
#  '2731',
#  '2fa',
#  '30',
#  '33',
#  '3402',
#  '35',
#  '365',
#  '37',
#  '3rd',
#  '40',
#  '443',
#  '60',
#  '6671',
#  '80',
#  '800',
#  '802',
#  '88',
#  '90',
#  'ability',
#  'able',
#  'abuse',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'access',
#  'accessed',
#  'accessible',
#  'accessing',
#  'accesssed',
#  'accidental',
#  'accordance',
#  'according',
#  'account',
#  'accounting',
#  'accounts',
#  'accuracy',
#  'acknowledge',
#  'acquisition',
#  'acted',
#  'action',
#  'actioned',
#  'actions',
#  'activate',
#  'activating',
#  'active',
#  'actively',
#  'activex',
#  'activities',
#  'activity',
#  'ad',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'addressed',
#  'addresses',
#  'addressing',
#  'adequacy',
#  'adjustment',
#  'admin',
#  'administration',
#  'administrative',
#  'administrator',
#  'administrators',
#  'adopted',
#  'advertising',
#  'advises',
#  'affect',
#  'affected',
#  'agencies',
#  'agents',
#  'agile',
#  'agreed',
#  'agreement',
#  'agreements',
#  'ajax',
#  'alarm',
#  'alarmed',
#  'alert',
#  'alerting',
#  'alerts',
#  'alignment',
#  'allocated',
#  'allow',
#  'allowed',
#  'allows',
#  'altered',
#  'alternate',
#  'amend',
#  'analysis',
#  'analytical',
#  'analyze',
#  'analyzed',
#  'android',
#  'anlaysis',
#  'annual',
#  'annually',
#  'anti',
#  'antivirus',
#  'anytime',
#  'api',
#  'apis',
#  'applets',
#  'applicable',
#  'application',
#  'applications',
#  'applied',
#  'apply',
#  'approach',
#  'approaches',
#  'appropriate',
#  'appropriately',
#  'approval',
#  'approvals',
#  'approve',
#  'approved',
#  'approving',
#  'apps',
#  'architectural',
#  'architecture',
#  'area',
#  'areas',
#  'arising',
#  'arrangement',
#  'aside',
#  'aspx',
#  'assembling',
#  'assess',
#  'assessee',
#  'assessees',
#  'assessing',
#  'assessment',
#  'assessments',
#  'asset',
#  'assets',
#  'assigned',
#  'assigning',
#  'assignments',
#  'assistance',
#  'associate',
#  'associated',
#  'associations',
#  'assurance',
#  'assure',
#  'asymmetric',
#  'attack',
#  'attacks',
#  'attainment',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attendance',
#  'attributes',
#  'audit',
#  'auditing',
#  'auditors',
#  'audits',
#  'auth',
#  'authenticated',
#  'authentication',
#  'author',
#  'authorities',
#  'authority',
#  'authorization',
#  'authorized',
#  'automated',
#  'automatic',
#  'availability',
#  'available',
#  'avaya',
#  'avoid',
#  'awareness',
#  'aws',
#  'azure',
#  'background',
#  'backup',
#  'backups',
#  'badges',
#  'banners',
#  'base',
#  'based',
#  'baseline',
#  'basis',
#  'batch',
#  'batteries',
#  'battery',
#  'bcms',
#  'bcp',
#  'behalf',
#  'benchmark',
#  'benchmarks',
#  'best',
#  'binaries',
#  'binary',
#  'bins',
#  'biometric',
#  'biometrics',
#  'bit',
#  'biweekly',
#  'black',
#  'blacklist',
#  'blacklisted',
#  'block',
#  'blocking',
#  'board',
#  'boarding',
#  'boards',
#  'bottlenecks',
#  'bouncycastle',
#  'boundary',
#  'box',
#  'breach',
#  'bribery',
#  'bridged',
#  'bring',
#  'browswer',
#  'bugs',
#  'build',
#  'building',
#  'buildings',
#  'built',
#  'business',
#  'byod',
#  'byon',
#  'cabinet',
#  'cable',
#  'calculated',
#  'calculation',
#  'called',
#  'calls',
#  'cameras',
#  'capabilities',
#  'capability',
#  'capacity',
#  'capturing',
#  'card',
#  'cards',
#  'case',
#  'cases',
#  'cause',
#  'ccna',
#  'ccnp',
#  'cctv',
#  'cd',
#  'cds',
#  'ceh',
#  'ceiling',
#  'cell',
#  'center',
#  'centers',
#  'central',
#  'centrally',
#  'certain',
#  'certificate',
#  'certificates',
#  'certification',
#  'certifications',
#  'chain',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channels',
#  'characters',
#  'chat',
#  'checked',
#  'checking',
#  'checks',
#  'cilent',
#  'cipher',
#  'circumstances',
#  'cis',
#  'cissp',
#  'citrix',
#  'cl',
#  'class',
#  'classes',
#  'classification',
#  'classified',
#  'classify',
#  'clean',
#  'clearly',
#  'client',
#  'clients',
#  'clock',
#  'closed',
#  'cloud',
#  'cobit',
#  'code',
#  'codeofbusinessconductandethics',
#  'collect',
#  'collected',
#  'collection',
#  'com',
#  'command',
#  'commensurate',
#  'commit',
#  'commitment',
#  'committee',
#  'common',
#  'communicated',
#  'communication',
#  'communications',
#  'community',
#  'company',
#  'compass',
#  'compensating',
#  'competence',
#  'competencies',
#  'complaints',
#  'complete',
#  'complex',
#  'complexity',
#  'compliance',
#  'components',
#  'comprehensive',
#  'compromise',
#  'computer',
#  'computers',
#  'computing',
#  'comunicated',
#  'concerns',
#  'condition',
#  'conditions',
#  'conduct',
#  'conducted',
#  'conducting',
#  'confidential',
#  'confidentiality',
#  'configuration',
#  'configured',
#  'confirm',
#  'connect',
#  'connected',
#  'connecting',
#  'connection',
#  'connections',
#  'consequences',
#  'considered',
#  'consistency',
#  'consistent',
#  'consists',
#  'consoles',
#  'constituent',
#  'constituents',
#  'consume',
#  'contact',
#  'contacts',
#  'contain',
#  'contained',
#  'container',
#  'containers',
#  'containing',
#  'containment',
#  'contains',
#  'content',
#  'continuity',
#  'continuous',
#  'continuously',
#  'contract',
#  'contractors',
#  'contracts',
#  'contractual',
#  'control',
#  'controlcenter',
#  'controled',
#  'controlled',
#  'controls',
#  'conversations',
#  'coordinated',
#  'coordinators',
#  'cope',
#  'copied',
#  'copies',
#  'copying',
#  'core',
#  'corporate',
#  'correct',
#  'corrected',
#  'correction',
#  'corrective',
#  'corruption',
#  'cots',
#  'countries',
#  'cover',
#  'covered',
#  'covering',
#  'cracking',
#  'crawl',
#  'create',
#  'created',
#  'creation',
#  'credential',
#  'credentials',
#  'credit',
#  'criteria',
#  'critical',
#  'criticality',
#  'cross',
#  'cryptographic',
#  'cryptography',
#  'ctp',
#  'current',
#  'curriculum',
#  'custody',
#  'custom',
#  'customer',
#  'customers',
#  'customized',
#  'cwe',
#  'cy18',
#  'cyber',
#  'cycle',
#  'cycles',
#  'daily',
#  'dashboard',
#  'dast',
#  'data',
#  'database',
#  'databases',
#  'datacaenters',
#  'datacenter',
#  'datacenters',
#  'datasets',
#  'datastores',
#  'date',
#  'day',
#  'days',
#  'dban',
#  'dealing',
#  'dealt',
#  'declaring',
#  'dedicated',
#  'deemed',
#  'default',
#  'defaults',
#  'defects',
#  'define',
#  'defined',
#  'defining',
#  'definitions',
#  'delete',
#  'deleted',
#  'deletion',
#  'deliberate',
#  'delivered',
#  'delivers',
#  'delivery',
#  'denial',
#  'deny',
#  'department',
#  'departments',
#  'depending',
#  'depends',
#  'deployed',
#  'deploying',
#  'deployment',
#  'depth',
#  'derived',
#  'design',
#  'designated',
#  'designates',
#  'designed',
#  'desired',
#  'desk',
#  'desktop',
#  'desktops',
#  'destroyed',
#  'destruction',
#  'details',
#  'detect',
#  'detected',
#  'detection',
#  'detective',
#  'determination',
#  'determinations',
#  'determine',
#  'determined',
#  'determining',
#  'dev',
#  'develop',
#  'developed',
#  'developers',
#  'development',
#  'device',
#  'devices',
#  'diagnosis',
#  'diagnostic',
#  'did',
#  'different',
#  'digitally',
#  'diligence',
#  'direct',
#  'directly',
#  'directors',
#  'directory',
#  'disable',
#  'disabled',
#  'disabling',
#  'disallowed',
#  'disaster',
#  'disciplinary',
#  'disclose',
#  'disclosure',
#  'disclosures',
#  'disconnected',
#  'discovered',
#  'discrepancies',
#  'discuss',
#  'disease',
#  'disk',
#  'displayed',
#  'displays',
#  'disposal',
#  'dispose',
#  'disruption',
#  'disruptions',
#  'disruptive',
#  'distinguishes',
#  'distributed',
#  'diverse',
#  'divided',
#  'dlt',
#  'dmz',
#  'doc_downloads',
#  'dock',
#  'docker',
#  'document',
#  'documentation',
#  'documented',
#  'documents',
#  'does',
#  'doors',
#  'dos',
#  'downtime',
#  'drive',
#  'drives',
#  'dsl',
#  'duties',
#  'dvd',
#  'dvds',
#  'dynamic',
#  'eap',
#  'ecosystem',
#  'edge',
#  'education',
#  'effective',
#  'effectiveness',
#  'effort',
#  'efforts',
#  'electronic',
#  'electronically',
#  'elements',
#  'eliminated',
#  'email',
#  'emails',
#  'emergency',
#  'employed',
#  'employee',
#  'employees',
#  'employment',
#  'employs',
#  'enable',
#  'enabled',
#  'enabling',
#  'encourages',
#  'encrypt',
#  'encrypted',
#  'encrypting',
#  'encryption',
#  'end',
#  'endpoint',
#  'enforce',
#  'enforced',
#  'enforcement',
#  'enforces',
#  'engaged',
#  'engages',
#  'engine',
#  'engineering',
#  'engineers',
#  'engines',
#  'enhance',
#  'ensure',
#  'ensures',
#  'ensuring',
#  'entered',
#  'enterpise',
#  'enterprise',
#  'entire',
#  'entitled',
#  'entitlement',
#  'entitlements',
#  'entity',
#  'entry',
#  'enviornments',
#  'environment',
#  'environmental',
#  'environments',
#  'equipment',
#  'equipped',
#  'eradication',
#  'erased',
#  'error',
#  'errors',
#  'escalate',
#  'escalated',
#  'escalation',
#  'escorted',
#  'essential',
#  'establish',
#  'established',
#  'establishing',
#  'establishment',
#  'ethical',
#  'ethics',
#  'evaluate',
#  'evaluated',
#  'evaluation',
#  'event',
#  'events',
#  'evidence',
#  'exception',
#  'exceptions',
#  'exchange',
#  'excluded',
#  'exclusions',
#  'executables',
#  'execute',
#  'executed',
#  'executing',
#  'execution',
#  'executive',
#  'exercise',
#  'exercises',
#  'exercising',
#  'exist',
#  'existing',
#  'exit',
#  'exits',
#  'expectations',
#  'expedited',
#  'expedites',
#  'experienced',
#  'expertise',
#  'experts',
#  'expiration',
#  'explain',
#  'exploitation',
#  'exploits',
#  'exposure',
#  'extend',
#  'extending',
#  'extensive',
#  'exterior',
#  'external',
#  'externally',
#  'extraction',
#  'extranet',
#  'facilities',
#  'facility',
#  'facing',
#  'factor',
#  'factors',
#  'factset',
#  'failed',
#  'failover',
#  'fails',
#  'failure',
#  'failures',
#  'fall',
#  'false',
#  'feature',
#  'features',
#  'fed',
#  'feedback',
#  'feeds',
#  'fields',
#  'file',
#  'files',
#  'filter',
#  'financial',
#  'findings',
#  'finished',
#  'fips',
#  'firewall',
#  'firewalls',
#  'firm',
#  'fixes',
#  'floor',
#  'floppy',
#  'flows',
#  'fob',
#  'focused',
#  'folders',
#  'follow',
#  'followed',
#  'following',
#  'follows',
#  'forced',
#  'forensic',
#  'form',
#  'formal',
#  'formally',
#  'forums',
#  'framework',
#  'frameworks',
#  'fraud',
#  'freeware',
#  'frequency',
#  'fuel',
#  'fully',
#  'function',
#  'functional',
#  'functionality',
#  'functioning',
#  'functions',
#  'funding',
#  'fuzz',
#  'fuzzing',
#  'gain',
#  'gap',
#  'gateways',
#  'general',
#  'generally',
#  'generate',
#  'generated',
#  'generates',
#  'generation',
#  'generator',
#  'generators',
#  'given',
#  'glass',
#  'global',
#  'goals',
#  'google',
#  'govdoc',
#  'govern',
#  'governance',
#  'government',
#  'granting',
#  'granular',
#  'green',
#  'group',
#  'grouping',
#  'groups',
#  'guard',
#  'guards',
#  'guest',
#  'guided',
#  'guideline',
#  'guidelines',
#  'hacking',
#  'handheld',
#  'handled',
#  'handling',
#  'happens',
#  'hard',
#  'hardened',
#  'hardening',
#  'hardware',
#  'hashed',
#  'health',
#  'heat',
#  'help',
#  'high',
#  'higher',
#  'highly',
#  'hinge',
#  'hipaa',
#  'hire',
#  'history',
#  'hitech',
#  'hoc',
#  'hold',
#  'holdings',
#  'host',
#  'hosted',
#  'hosting',
#  'hosts',
#  'hot',
#  'hotspots',
#  'hour',
#  'hours',
#  'house',
#  'hr',
#  'hsm',
#  'http',
#  'https',
#  'human',
#  'humidity',
#  'hvac',
#  'hybrid',
#  'hydrogen',
#  'hypervisor',
#  'hypervisors',
#  'iaas',
#  'ica',
#  'id',
#  'identifiable',
#  'identification',
#  'identified',
#  'identifies',
#  'identify',
#  'identifying',
#  'identity',
#  'idle',
#  'ids',
#  'image',
#  'images',
#  'immediately',
#  'impact',
#  'impacted',
#  'impacting',
#  'implement',
#  'implementation',
#  'implemented',
#  'implementing',
#  'importance',
#  'improvement',
#  'improvements',
#  'inaccurate',
#  'inactive',
#  'inactivity',
#  'inadvertent',
#  'inappropriate',
#  'inbound',
#  'incident',
#  'incidents',
#  'include',
#  'included',
#  'includes',
#  'including',
#  'incomplete',
#  'incorporate',
#  'independent',
#  'independently',
#  'indicate',
#  'indication',
#  'individual',
#  'individuals',
#  'industry',
#  'infections',
#  'infectious',
#  'influenza',
#  'info',
#  'information',
#  'infrastructure',
#  'initial',
#  'initially',
#  'initiate',
#  'initital',
#  'injection',
#  'injections',
#  'input',
#  'inputs',
#  'insert',
#  'inside',
#  'insider',
#  'inspect',
#  'inspection',
#  'installation',
#  'installed',
#  'installing',
#  'instance',
#  'instances',
#  'instantiated',
#  'insure',
#  'integrated',
#  'integration',
#  'integrity',
#  'intellectual',
#  'intelligent',
#  'intended',
#  'interact',
#  'interacting',
#  'interaction',
#  'interactions',
#  'interactive',
#  'intercepted',
#  'interested',
#  'interface',
#  'interfaces',
#  'internal',
#  'internally',
#  'internet',
#  'interruptions',
#  'interval',
#  'intervals',
#  'intervention',
#  'intranet',
#  'introduction',
#  'introspection',
#  'intrusion',
#  'invalid',
#  'inventoried',
#  'inventory',
#  'investigate',
#  'investigates',
#  'investigating',
#  'investigation',
#  'investor',
#  'investors',
#  'invoke',
#  'invoked',
#  'involve',
#  'involved',
#  'involving',
#  'ios',
#  'ip',
#  'ips',
#  'iron',
#  'isae',
#  'iso',
#  'isolate',
#  'isolated',
#  'isolation',
#  'issue',
#  'issued',
#  'issues',
#  'issuing',
#  'itil',
#  'java',
#  'javascript',
#  'job',
#  'joining',
#  'joint',
#  'jurisdictions',
#  'kept',
#  'kernel',
#  'key',
#  'keys',
#  'kill',
#  'knowingly',
#  'knowledge',
#  'known',
#  'labeling',
#  'lan',
#  'laptops',
#  'large',
#  'latest',
#  'law',
#  'laws',
#  'layer',
#  'layered',
#  'leadership',
#  'leading',
#  'leakage',
#  'learned',
#  'learning',
#  'leaving',
#  'led',
#  'left',
#  'leftover',
#  'legacy',
#  'legal',
#  'legislation',
#  'legislative',
#  'length',
#  'lessons',
#  'letters',
#  'level',
#  'levels',
#  'leverage',
#  'leveraged',
#  'leverages',
#  'libraries',
#  'library',
#  'license',
#  'licensing',
#  'life',
#  'lifecycle',
#  'lighting',
#  'like',
#  'limit',
#  'limited',
#  'line',
#  'list',
#  'lists',
#  ...]

# %%
vect = CountVectorizer(stop_words='english', ngram_range=(1,2), min_df=1)
tokenize_test(vect)
# Out:
# Number of features:  8258
# Accuracy:  0.656666666667

# %% [markdown]
# # Textblob

# %%
question = TextBlob(classifier.loc[0, 'question'])

# %%
question
# Out:
# TextBlob("Is there a risk assessment program that has been approved by management, communicated to constituents and an owner to maintain and review the program? if yes, does it include:")

# %%
stemmer = SnowballStemmer('english')

# %%
question.words
# Out:
# WordList(['Is', 'there', 'a', 'risk', 'assessment', 'program', 'that', 'has', 'been', 'approved', 'by', 'management', 'communicated', 'to', 'constituents', 'and', 'an', 'owner', 'to', 'maintain', 'and', 'review', 'the', 'program', 'if', 'yes', 'does', 'it', 'include'])

# %%
#Stemmer is crude form
[stemmer.stem(word) for word in question.words]
# Out:
# ['is',
#  'there',
#  'a',
#  'risk',
#  'assess',
#  'program',
#  'that',
#  'has',
#  'been',
#  'approv',
#  'by',
#  'manag',
#  'communic',
#  'to',
#  'constitu',
#  'and',
#  'an',
#  'owner',
#  'to',
#  'maintain',
#  'and',
#  'review',
#  'the',
#  'program',
#  'if',
#  'yes',
#  'doe',
#  'it',
#  'includ']

# %%
print([word.lemmatize(pos='v') for word in question.words])
# Out:
# ['Is', 'there', 'a', 'risk', 'assessment', 'program', 'that', 'have', 'be', 'approve', 'by', 'management', 'communicate', 'to', 'constituents', 'and', 'an', 'owner', 'to', 'maintain', 'and', 'review', 'the', 'program', 'if', 'yes', 'do', 'it', 'include']

# %%
def split_into_lemmas(text):
    text = str(text).lower()
    words = TextBlob(text).words
    return (word.lemmatize(pos='v') for word in words)

# %%
vect = CountVectorizer(stop_words ='english', analyzer=split_into_lemmas, decode_error='replace', ngram_range=(1,1), min_df=3)
tokenize_test(vect)
# Out:
# Number of features:  851
# Accuracy:  0.666666666667

# %%
classifier
# Out:
#      question_num                                           question response  \
# 0             A.1  Is there a risk assessment program that has be...      Yes
# 1           A.1.1  A risk assessment, conducted within the last 1...      Yes
# 2           A.1.2                                   Risk Governance?      Yes
# 3           A.1.3  Range of assets to include: people, processes,...      Yes
# 4           A.1.4  Range of threats to include: malicious, natura...      Yes
# 5           A.1.5                                      Risk scoping?      Yes
# 6           A.1.6                                      Risk context?      Yes
# 7           A.1.7                                Risk training plan?      Yes
# 8           A.1.8                          Risk evaluation criteria?      Yes
# 9           A.1.9           Risk scenarios? If yes, do they include:      Yes
# 10        A.1.9.1  Events and possible threats that could impact ...      Yes
# 11        A.1.9.2                                      Threat types?      Yes
# 12         A.1.10  Ownership, action plan, response plan, managem...      Yes
# 13            A.2  Is there a program to manage the treatment of ...      Yes
# 14          A.2.1  A formal process for assigning appropriate man...      Yes
# 15          A.2.2  A formal process for appropriate management kn...      Yes
# 16          A.2.3  A formal process for tracking the status of ac...      Yes
# 17          A.2.4        Controls identified for each material risk?      Yes
# 18          A.2.5  Measures for defining, monitoring, and reporti...      Yes
# 19        A.2.5.1                            Performance benchmarks?      Yes
# 20        A.2.5.2                Service Level Agreement Compliance?      Yes
# 21        A.2.5.3                                 Policy Compliance?      Yes
# 22        A.2.5.4                             Control Effectiveness?      Yes
# 23        A.2.5.5                          Vulnerability Management?      Yes
# 24            A.3  Do Subcontractors have access to Scoped System...       No
# 25            A.4              Is there a vendor management program?      Yes
# 26          A.4.1  Does the vendor management program include an ...       No
# 27        A.4.1.1  Risk rating of the issue (e.g., H/M/L, 1-5, et...       No
# 28        A.4.1.2                                 Remediation plans?       No
# 29        A.4.1.3                                  Remediation date?       No
# ...           ...                                                ...      ...
# 1167    U.1.37.15       Password change requirements at first logon?      n/a
# 1168    U.1.37.16  Stand alone authentication requirements such a...       No
# 1169    U.1.37.17                    Passwords encrypted in transit?      Yes
# 1170    U.1.37.18          Passwords encrypted or hashed in storage?      Yes
# 1171    U.1.37.19    Passwords displayed when entered into a system?       No
# 1172    U.1.37.20   User accounts associated to a unique individual?      Yes
# 1173    U.1.37.21  System lock requirements after 3-5 invalid log...       No
# 1174    U.1.37.22  Restricted administrative access to the manage...      Yes
# 1175    U.1.37.23  Disabling unneeded hypervisor services (e.g., ...      Yes
# 1176    U.1.37.24  Introspection capabilities to monitor the secu...      Yes
# 1177    U.1.37.25  Introspection capabilities to monitor the secu...      Yes
# 1178    U.1.37.26  Separate network VLANs for host operating syst...      Yes
# 1179    U.1.37.27  Guest operating systems communicate on separat...       No
# 1180    U.1.37.28  Host operating system management interface on ...      Yes
# 1181    U.1.37.29  Two factor authentication for access to the ad...      Yes
# 1182    U.1.37.30  Approval process before VMs can be created to ...      Yes
# 1183    U.1.37.31  Migration of VMs logged including source and t...      Yes
# 1184    U.1.37.32  VM's in the same host sharing the risk and dat...      Yes
# 1185    U.1.37.33  VM's in the same host sharing system sensitivi...      Yes
# 1186       U.1.38  Are Data Containers used to process or store S...      Yes
# 1187     U.1.38.1  Can clients prohibit containers from being use...       No
# 1188     U.1.38.2  Is there a Data Container (e.g. Docker) Securi...      Yes
# 1189     U.1.38.3  Security requirements implemented as part of t...      Yes
# 1190     U.1.38.4  Data Containers on the same host share share t...      Yes
# 1191     U.1.38.5  External Container images to be signed and ori...      n/a
# 1192     U.1.38.6  Containers are scanned for vulnerabilities and...      Yes
# 1193     U.1.38.7  Seccomp profiles are enabled to reduce the num...       No
# 1194     U.1.38.8               An Authorization Plug-In is enabled?       No
# 1195     U.1.38.9  Control Groups are enabled to reduce the kerne...      Yes
# 1196    U.1.38.10  Linux User Namespace Support is enabled to red...      Yes
#
#       maturity                                          misc_info  \
# 0          5.0  An enterprise risk assessment is performed ann...
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         5.0  Risk ratings are assigned, documented and trac...
# 14         NaN                                     Please see A.2
# 15         NaN  Certain exceptions are documented and accepted...
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN  With the exception of third party data feeds a...
# 25         4.0                                     Please see A.3
# 26         NaN  An initital due diligence assessment is perfor...
# 27         NaN
# 28         NaN
# 29         NaN
# ...        ...                                                ...
# 1167       NaN                                      see U.1.37.11
# 1168       NaN                    This use case is not supported.
# 1169       NaN
# 1170       NaN
# 1171       NaN                              Passwords are masked.
# 1172       NaN
# 1173       NaN  System lock occurs at higher invalid login att...
# 1174       NaN
# 1175       NaN
# 1176       NaN
# 1177       NaN
# 1178       NaN
# 1179       NaN  FactSet's multi-tenant virtualized environment...
# 1180       NaN
# 1181       NaN
# 1182       NaN
# 1183       NaN
# 1184       NaN
# 1185       NaN
# 1186       NaN
# 1187       NaN
# 1188       NaN
# 1189       NaN
# 1190       NaN
# 1191       NaN                       External containers not used
# 1192       NaN
# 1193       NaN
# 1194       NaN
# 1195       NaN
# 1196       NaN
#
#                                                 aup_ref       iso_num  \
# 0               A.1 IT & Infrastructure Risk Governance     5.1 6.1.2
# 1     A.2 IT & Infrastructure Risk Assessment Life C...           8.2
# 2               A.1 IT & Infrastructure Risk Governance           NaN
# 3               A.1 IT & Infrastructure Risk Governance           NaN
# 4               A.1 IT & Infrastructure Risk Governance         6.1.2
# 5               A.1 IT & Infrastructure Risk Governance         6.1.2
# 6               A.1 IT & Infrastructure Risk Governance         6.1.2
# 7               A.1 IT & Infrastructure Risk Governance         6.1.2
# 8               A.1 IT & Infrastructure Risk Governance         6.1.2
# 9               A.1 IT & Infrastructure Risk Governance         6.1.2
# 10              A.1 IT & Infrastructure Risk Governance         6.1.2
# 11              A.1 IT & Infrastructure Risk Governance         6.1.2
# 12    A.2 IT & Infrastructure Risk Assessment Life C...         6.1.2
# 13    A.2 IT & Infrastructure Risk Assessment Life C...         6.1.3
# 14    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 15    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 16    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 17    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 18    A.2 IT & Infrastructure Risk Assessment Life C...           NaN
# 19                                                                NaN
# 20                                                                NaN
# 21                                                                NaN
# 22                                                                NaN
# 23                                                                NaN
# 24                                                                 15
# 25                   A.5 Vendor Risk Management Program           NaN
# 26                                                                NaN
# 27                   A.5 Vendor Risk Management Program           NaN
# 28                   A.5 Vendor Risk Management Program           NaN
# 29                   A.5 Vendor Risk Management Program           NaN
# ...                                                 ...           ...
# 1167                              H.1 Password Controls         9.3.1
# 1168                              H.1 Password Controls         9.3.1
# 1169                              H.1 Password Controls  9.3.1 10.1.1
# 1170                              H.1 Password Controls         9.3.1
# 1171                              H.1 Password Controls         9.3.1
# 1172                              H.1 Password Controls        9.2.1
# 1173                                                           9.2.4
# 1174                   H.3 Logical Access Authorization   9.1.1 9.2.3
# 1175    V.4 Security Review of Hypervisor Configuration         9.4.1
# 1176    V.4 Security Review of Hypervisor Configuration        12.4.1
# 1177    V.4 Security Review of Hypervisor Configuration        12.4.1
# 1178    V.4 Security Review of Hypervisor Configuration        13.1.3
# 1179    V.4 Security Review of Hypervisor Configuration        13.1.3
# 1180    V.4 Security Review of Hypervisor Configuration        13.1.3
# 1181    V.4 Security Review of Hypervisor Configuration         9.1.1
# 1182    V.4 Security Review of Hypervisor Configuration        12.1.2
# 1183    V.4 Security Review of Hypervisor Configuration        12.4.1
# 1184    V.4 Security Review of Hypervisor Configuration        12.1.4
# 1185    V.4 Security Review of Hypervisor Configuration        12.1.4
# 1186                                                              NaN
# 1187                                                              NaN
# 1188                                                              NaN
# 1189                                                              NaN
# 1190                                                              NaN
# 1191                                                              NaN
# 1192                                                              NaN
# 1193                                                              NaN
# 1194                                                              NaN
# 1195                                                              NaN
# 1196                                                              NaN
#
#                                                iso_desc        sig_class  \
# 0     Leadership & Commitment, Information Security ...  Risk Assessment
# 1                  Information security risk assessment  Risk Assessment
# 2                                                        Risk Assessment
# 3                                                        Risk Assessment
# 4                  Information Security Risk Assessment  Risk Assessment
# 5                  Information Security Risk Assessment  Risk Assessment
# 6                  Information Security Risk Assessment  Risk Assessment
# 7                  Information Security Risk Assessment  Risk Assessment
# 8                  Information Security Risk Assessment  Risk Assessment
# 9                  Information Security Risk Assessment  Risk Assessment
# 10                 Information Security Risk Assessment  Risk Assessment
# 11                 Information Security Risk Assessment  Risk Assessment
# 12                 Information Security Risk Assessment  Risk Assessment
# 13                  Information Security Risk treatment  Risk Assessment
# 14                                                       Risk Assessment
# 15                                                       Risk Assessment
# 16                                                       Risk Assessment
# 17                                                       Risk Assessment
# 18                                                       Risk Assessment
# 19                                                       Risk Assessment
# 20                                                       Risk Assessment
# 21                                                       Risk Assessment
# 22                                                       Risk Assessment
# 23                                                       Risk Assessment
# 24                               Supplier relationships  Risk Assessment
# 25                                                       Risk Assessment
# 26                                                       Risk Assessment
# 27                                                       Risk Assessment
# 28                                                       Risk Assessment
# 29                                                       Risk Assessment
# ...                                                 ...              ...
# 1167           Use of secret authentication information  Server Security
# 1168           Use of secret authentication information  Server Security
# 1169  Use of secret authentication information, Poli...  Server Security
# 1170           Use of secret authentication information  Server Security
# 1171           Use of secret authentication information  Server Security
# 1172              User registration and de-registration  Server Security
# 1173  Management of secret authentication informatio...  Server Security
# 1174  Access control policy, Management of privilege...  Server Security
# 1175                     Information access restriction  Server Security
# 1176                                      Event logging  Server Security
# 1177                                      Event logging  Server Security
# 1178                            Segregation in networks  Server Security
# 1179                            Segregation in networks  Server Security
# 1180                            Segregation in networks  Server Security
# 1181                              Access control policy  Server Security
# 1182                                  Change Management  Server Security
# 1183                                      Event logging  Server Security
# 1184  Separation of Development, Test, And Operation...  Server Security
# 1185  Separation of Development, Test, And Operation...  Server Security
# 1186                                                     Server Security
# 1187                                                     Server Security
# 1188                                                     Server Security
# 1189                                                     Server Security
# 1190                                                     Server Security
# 1191                                                     Server Security
# 1192                                                     Server Security
# 1193                                                     Server Security
# 1194                                                     Server Security
# 1195                                                     Server Security
# 1196                                                     Server Security
#
#       sig_class_num                                          textfield
# 0                11  Is there a risk assessment program that has be...
# 1                11  A risk assessment, conducted within the last 1...
# 2                11  Risk Governance?   A.1 IT & Infrastructure Ris...
# 3                11  Range of assets to include: people, processes,...
# 4                11  Range of threats to include: malicious, natura...
# 5                11  Risk scoping?  Information Security Risk Asses...
# 6                11  Risk context?  Information Security Risk Asses...
# 7                11  Risk training plan?  Information Security Risk...
# 8                11  Risk evaluation criteria?  Information Securit...
# 9                11  Risk scenarios? If yes, do they include:  Info...
# 10               11  Events and possible threats that could impact ...
# 11               11  Threat types?  Information Security Risk Asses...
# 12               11  Ownership, action plan, response plan, managem...
# 13               11  Is there a program to manage the treatment of ...
# 14               11  A formal process for assigning appropriate man...
# 15               11  A formal process for appropriate management kn...
# 16               11  A formal process for tracking the status of ac...
# 17               11  Controls identified for each material risk?   ...
# 18               11  Measures for defining, monitoring, and reporti...
# 19               11                         Performance benchmarks?
# 20               11             Service Level Agreement Compliance?
# 21               11                              Policy Compliance?
# 22               11                          Control Effectiveness?
# 23               11                       Vulnerability Management?
# 24               11  Do Subcontractors have access to Scoped System...
# 25               11  Is there a vendor management program? Please s...
# 26               11  Does the vendor management program include an ...
# 27               11  Risk rating of the issue (e.g., H/M/L, 1-5, et...
# 28               11  Remediation plans?   A.5 Vendor Risk Managemen...
# 29               11  Remediation date?   A.5 Vendor Risk Management...
# ...             ...                                                ...
# 1167              5  Password change requirements at first logon? s...
# 1168              5  Stand alone authentication requirements such a...
# 1169              5  Passwords encrypted in transit?  Use of secret...
# 1170              5  Passwords encrypted or hashed in storage?  Use...
# 1171              5  Passwords displayed when entered into a system...
# 1172              5  User accounts associated to a unique individua...
# 1173              5  System lock requirements after 3-5 invalid log...
# 1174              5  Restricted administrative access to the manage...
# 1175              5  Disabling unneeded hypervisor services (e.g., ...
# 1176              5  Introspection capabilities to monitor the secu...
# 1177              5  Introspection capabilities to monitor the secu...
# 1178              5  Separate network VLANs for host operating syst...
# 1179              5  Guest operating systems communicate on separat...
# 1180              5  Host operating system management interface on ...
# 1181              5  Two factor authentication for access to the ad...
# 1182              5  Approval process before VMs can be created to ...
# 1183              5  Migration of VMs logged including source and t...
# 1184              5  VM's in the same host sharing the risk and dat...
# 1185              5  VM's in the same host sharing system sensitivi...
# 1186              5  Are Data Containers used to process or store S...
# 1187              5  Can clients prohibit containers from being use...
# 1188              5  Is there a Data Container (e.g. Docker) Securi...
# 1189              5  Security requirements implemented as part of t...
# 1190              5  Data Containers on the same host share share t...
# 1191              5  External Container images to be signed and ori...
# 1192              5  Containers are scanned for vulnerabilities and...
# 1193              5  Seccomp profiles are enabled to reduce the num...
# 1194              5            An Authorization Plug-In is enabled?
# 1195              5  Control Groups are enabled to reduce the kerne...
# 1196              5  Linux User Namespace Support is enabled to red...
#
# [1197 rows x 11 columns]

# %%
#help(LogisticRegression())

# %% [markdown]
# # Deploy model on TRC_Master Data

# %%
trc_file = './data/trc_master_train_data.csv'

# %%
trc_test_data = pd.read_csv(trc_file, encoding='latin1')

# %%
trc_test_data
# Out:
#                                                     Tag  \
# 0                                        access control
# 1                                        access control
# 2                                        access control
# 3                                 access control policy
# 4                                      Access Control,
# 5                             access control, accounts,
# 6           access control, authorization, system admin
# 7     access control, employee management system, le...
# 8                       access control, password policy
# 9           access control, password policy, encryption
# 10                Access Control, Review, access review
# 11                          access control, review, log
# 12                                       access removal
# 13    accounting system, upload, holdings, import, e...
# 14                                              ActiveX
# 15                           ActiveX, HTML, Flash, Java
# 16                                      addins, add-ins
# 17    admin access, admin rights, administrator acce...
# 18                                                alert
# 19                                 alert, vulnerability
# 20                                             alerting
# 21     Antivirus, anti-virus, anti-malware, antimalware
# 22     Antivirus, anti-virus, anti-malware, antimalware
# 23     Antivirus, anti-virus, anti-malware, antimalware
# 24     Antivirus, anti-virus, anti-malware, antimalware
# 25     Antivirus, anti-virus, anti-malware, antimalware
# 26     Antivirus, anti-virus, anti-malware, antimalware
# 27     Antivirus, anti-virus, anti-malware, antimalware
# 28     Antivirus, anti-virus, anti-malware, antimalware
# 29     Antivirus, anti-virus, anti-malware, antimalware
# ...                                                 ...
# 1039                                                NaN
# 1040                                                NaN
# 1041                                                NaN
# 1042                                                NaN
# 1043                                                NaN
# 1044                                                NaN
# 1045                                                NaN
# 1046                                                NaN
# 1047                                                NaN
# 1048                                                NaN
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054                                                NaN
# 1055                                                NaN
# 1056                                                NaN
# 1057                                                NaN
# 1058                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1062                                                NaN
# 1063                                                NaN
# 1064                                                NaN
# 1065                                                NaN
# 1066                                                NaN
# 1067                                                NaN
# 1068                                                NaN
#
#                                                Question  \
# 0     Are all system login screens configured to dis...
# 1     Does your company disable default privileged a...
# 2                                                   NaN
# 3        copy of your Access Control Policy and process
# 4     Please explain who initiates and approves the ...
# 5     Is there a dedicated team tasked with create/a...
# 6                                 Who authorizes access
# 7     How are your internal users (employees) grante...
# 8     Does your company enforce a user account creat...
# 9     Does your company require all passwords, inclu...
# 10    Access Control\n\nThe Service Provider will co...
# 11    When was the last time an application/technica...
# 12    Provide the time frame for removing access of ...
# 13                 How many of your clients use PORTIA?
# 14                                              ActiveX
# 15    Is any specific desktop / browser software req...
# 16    Concerning FactSet installing (setup) is it po...
# 17    Does the company restrict administrative acces...
# 18    Does the application provide alerts, notices, ...
# 19    Do you receive CERT Advisories from Carnegie M...
# 20    Does the Hosting Provider review violation rep...
# 21                 Do you use Anti-virus? Anti-malware?
# 22       Do you use anti-virus on ALL systems?  Explain
# 23              Do you use anti-virus on Email Systems?
# 24    How often are workstation anti-virus scans con...
# 25             Are all virus definitions updated daily?
# 26        How often are FULL antivirus scans performed?
# 27               Describe the signature update process.
# 28        How does FactSet prevent cross-contamination?
# 29    Are the malicious code prevention software upd...
# ...                                                 ...
# 1039                           Entitlements - Vermilion
# 1040                               Browser requirements
# 1041                                             Access
# 1042                                        Outsourcing
# 1043                                    Data separation
# 1044                           Virtualization Possible?
# 1045                                  BCP/DR - overview
# 1046                                  BCP/DR - overview
# 1047                                   BCP/DR - Testing
# 1048  BCP/DR - Testing - conducted in the last 12 mo...
# 1049  BCP/DR - Testing - conducted in the last 12 mo...
# 1050  BCP/DR - Testing - conducted in the last 12 mo...
# 1051                                  BCP/DR - overview
# 1052                                  BCP/DR - back-ups
# 1053                              Professional Services
# 1054                                  BCP/DR - back-ups
# 1055                        BCP/DR - back-ups frequency
# 1056                                  BCP/DR - back-ups
# 1057                                   BCP/DR - restore
# 1058                        BCP/DR - recovery capabilty
# 1059                              Information retention
# 1060                                   Data restoration
# 1061                                  Security Controls
# 1062                                   Managed Services
# 1063                                             SSAE16
# 1064                                                DLP
# 1065                         Authentication - Vermilion
# 1066                               ISAE3402 - Vermilion
# 1067                                    System recovery
# 1068                                         Monitoring
#
#                                                  Answer Updated date  \
# 0        This is in place for some, but not all systems          NaN
# 1          Privileged accounts granted based on role.            NaN
# 2     Only limited, named systems administrators hav...          NaN
# 3     Access is granted based on employee role.  Fac...          NaN
# 4     Access to systems and resources is role-based....          NaN
# 5     This is handled by the FactSet Systems Enginee...          NaN
# 6     FactSet server administrators grant access con...          NaN
# 7     Employees are issued user IDs specific to the ...          NaN
# 8     Account IDs are only reused if an employee or ...          NaN
# 9     This is true for all network, application and ...          NaN
# 10    Procedures are in place to review employee acc...          NaN
# 11    FactSet periodically reviews all internal and ...          NaN
# 12                                      Within 24 hours          NaN
# 13    FactSet has many clients successfully integrat...          NaN
# 14    The FactSet client software uses an ActiveX co...          NaN
# 15    FactSet is an installed application.  The Fact...          NaN
# 16    The FactSet add-ins for Office can be enabled/...          NaN
# 17    Administrative access is restricted in some ca...          NaN
# 18    FactSet supports many workflows  many of whic...          NaN
# 19    FactSets Security Teams monitor several sourc...          NaN
# 20    FactSet maintains an automated alert system, w...          NaN
# 21    This is in place where appropriate and necessa...    8/26/2017
# 22    No.  As necessary and appropriate.\n\n--\nOn f...    8/26/2017
# 23    Virus checking is in place on production mail ...    8/26/2017
# 24                                         In real time    8/26/2017
# 25                           Auto-updates are employed.    8/26/2017
# 26                                               Weekly    8/26/2017
# 27    Processes are in place to ensure enterprise PC...    8/26/2017
# 28    FactSet regularly scans devices, and auto upda...    8/26/2017
# 29    Yes.  FactSet has anti-malware built into our ...    8/26/2017
# ...                                                 ...          ...
# 1039  Client business users are able to apply indivi...    3/14/2018
# 1040  Hosted application access will be through a Ci...    7/19/2017
# 1041  Clients have no direct access to the critical ...    7/19/2017
# 1042  FactSet manages 100% of its hosting infrastruc...    7/10/2017
# 1043  FactSet's Enterprise Hosting pods, where the <...    7/10/2017
# 1044  <APPLICATION NAME> will be hosted by FactSet i...    6/22/2017
# 1045  FactSet Enterprise Hosting allows for various ...    6/22/2017
# 1046  FactSet Enterprise Hosting includes the option...    6/22/2017
# 1047  DR testing for single-tenant pods would be coo...    6/22/2017
# 1048  The underlying infrastructure that Enterprise ...    11/8/2017
# 1049  Yes.  While FactSets Enterprise Hosting is a ...    10/4/2017
# 1050  Yes.  While FactSets Enterprise Hosting is a ...   10/10/2017
# 1051  FactSet is able to deploy a client environment...    6/22/2017
# 1052  FactSet leverages multiple technologies to pro...    6/22/2017
# 1053  FactSet maintains all technical configurations...    6/22/2017
# 1054  Backups happen using automated technologies (s...    6/22/2017
# 1055  Data is backed up in realtime via Zerto synchr...    3/14/2018
# 1056  The system can remain online during back-ups (...    3/14/2018
# 1057  Failover to data-synchronized backup pods, or ...    6/22/2017
# 1058  For single-tenant hosted Performance and Repor...    3/13/2018
# 1059  FactSet retains all data in the system and doe...    1/22/2018
# 1060  FactSet provides database recovery in the even...    6/22/2017
# 1061  FactSet has a robust FactSet Enterprise System...    1/31/2018
# 1062  FactSet offers the following via our Enterpris...    7/11/2017
# 1063  FactSet's NJ datacenter is SSAE16 certified an...    11/3/2017
# 1064  Access to the environment is based on employee...          NaN
# 1065  Vermilion on FactSet Enterprise Hosting suppor...   12/13/2018
# 1066  FactSet is concluding an ISAE 3402 for Vermili...   12/13/2018
# 1067  FactSet Enterprise Hosting is a fully managed ...    3/14/2018
# 1068  FactSet has its own Central Logging Platform a...    3/14/2018
#
#      Answer provided by  Expiration Date
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# 5                   NaN              NaN
# 6                   NaN              NaN
# 7                   NaN              NaN
# 8                   NaN              NaN
# 9                   NaN              NaN
# 10                  NaN              NaN
# 11                  NaN              NaN
# 12                  NaN              NaN
# 13                  NaN              NaN
# 14                  NaN              NaN
# 15                  NaN              NaN
# 16                  NaN              NaN
# 17                  NaN              NaN
# 18                  NaN              NaN
# 19                  NaN              NaN
# 20                  NaN              NaN
# 21                  LCW              NaN
# 22                  LCW              NaN
# 23                  LCW              NaN
# 24                  LCW              NaN
# 25                  LCW              NaN
# 26                  LCW              NaN
# 27                  LCW              NaN
# 28                  LCW              NaN
# 29                  LCW              NaN
# ...                 ...              ...
# 1039                JMD              NaN
# 1040           Gota/Pat              NaN
# 1041           Gota/Pat              NaN
# 1042                JMD              NaN
# 1043                JMD              NaN
# 1044                JMD              NaN
# 1045                JMD              NaN
# 1046                JMD              NaN
# 1047                JMD              NaN
# 1048                JMD              NaN
# 1049                Pat              NaN
# 1050                Pat              NaN
# 1051                JMD              NaN
# 1052                JMD              NaN
# 1053                JMD              NaN
# 1054                JMD              NaN
# 1055                JMD              NaN
# 1056                JMD              NaN
# 1057                JMD              NaN
# 1058                JMD              NaN
# 1059                JMD              NaN
# 1060                JMD              NaN
# 1061                JMD              NaN
# 1062                Pat              NaN
# 1063                LCW              NaN
# 1064                MCW              NaN
# 1065                JMD              NaN
# 1066                JMD              NaN
# 1067                LCW              NaN
# 1068                LCW              NaN
#
# [1069 rows x 6 columns]

# %%
# Fill in NaN data with blanks
trc_test_data.loc[:, 'Tag'].fillna('', inplace=True)
trc_test_data.loc[:, 'Question'].fillna('', inplace=True)
trc_test_data.loc[:, 'Answer'].fillna('', inplace=True)

# %%
# Concatenate text columns
trc_test_data.loc[:, 'text_concat'] = (trc_test_data.loc[:, 'Tag'] + ' ' 
                                       + trc_test_data.loc[:, 'Question'] + ' ' 
                                       + trc_test_data.loc[:, 'Answer'])

# %%
trc_test_data
# Out:
#                                                     Tag  \
# 0                                        access control
# 1                                        access control
# 2                                        access control
# 3                                 access control policy
# 4                                      Access Control,
# 5                             access control, accounts,
# 6           access control, authorization, system admin
# 7     access control, employee management system, le...
# 8                       access control, password policy
# 9           access control, password policy, encryption
# 10                Access Control, Review, access review
# 11                          access control, review, log
# 12                                       access removal
# 13    accounting system, upload, holdings, import, e...
# 14                                              ActiveX
# 15                           ActiveX, HTML, Flash, Java
# 16                                      addins, add-ins
# 17    admin access, admin rights, administrator acce...
# 18                                                alert
# 19                                 alert, vulnerability
# 20                                             alerting
# 21     Antivirus, anti-virus, anti-malware, antimalware
# 22     Antivirus, anti-virus, anti-malware, antimalware
# 23     Antivirus, anti-virus, anti-malware, antimalware
# 24     Antivirus, anti-virus, anti-malware, antimalware
# 25     Antivirus, anti-virus, anti-malware, antimalware
# 26     Antivirus, anti-virus, anti-malware, antimalware
# 27     Antivirus, anti-virus, anti-malware, antimalware
# 28     Antivirus, anti-virus, anti-malware, antimalware
# 29     Antivirus, anti-virus, anti-malware, antimalware
# ...                                                 ...
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
#
#                                                Question  \
# 0     Are all system login screens configured to dis...
# 1     Does your company disable default privileged a...
# 2
# 3        copy of your Access Control Policy and process
# 4     Please explain who initiates and approves the ...
# 5     Is there a dedicated team tasked with create/a...
# 6                                 Who authorizes access
# 7     How are your internal users (employees) grante...
# 8     Does your company enforce a user account creat...
# 9     Does your company require all passwords, inclu...
# 10    Access Control\n\nThe Service Provider will co...
# 11    When was the last time an application/technica...
# 12    Provide the time frame for removing access of ...
# 13                 How many of your clients use PORTIA?
# 14                                              ActiveX
# 15    Is any specific desktop / browser software req...
# 16    Concerning FactSet installing (setup) is it po...
# 17    Does the company restrict administrative acces...
# 18    Does the application provide alerts, notices, ...
# 19    Do you receive CERT Advisories from Carnegie M...
# 20    Does the Hosting Provider review violation rep...
# 21                 Do you use Anti-virus? Anti-malware?
# 22       Do you use anti-virus on ALL systems?  Explain
# 23              Do you use anti-virus on Email Systems?
# 24    How often are workstation anti-virus scans con...
# 25             Are all virus definitions updated daily?
# 26        How often are FULL antivirus scans performed?
# 27               Describe the signature update process.
# 28        How does FactSet prevent cross-contamination?
# 29    Are the malicious code prevention software upd...
# ...                                                 ...
# 1039                           Entitlements - Vermilion
# 1040                               Browser requirements
# 1041                                             Access
# 1042                                        Outsourcing
# 1043                                    Data separation
# 1044                           Virtualization Possible?
# 1045                                  BCP/DR - overview
# 1046                                  BCP/DR - overview
# 1047                                   BCP/DR - Testing
# 1048  BCP/DR - Testing - conducted in the last 12 mo...
# 1049  BCP/DR - Testing - conducted in the last 12 mo...
# 1050  BCP/DR - Testing - conducted in the last 12 mo...
# 1051                                  BCP/DR - overview
# 1052                                  BCP/DR - back-ups
# 1053                              Professional Services
# 1054                                  BCP/DR - back-ups
# 1055                        BCP/DR - back-ups frequency
# 1056                                  BCP/DR - back-ups
# 1057                                   BCP/DR - restore
# 1058                        BCP/DR - recovery capabilty
# 1059                              Information retention
# 1060                                   Data restoration
# 1061                                  Security Controls
# 1062                                   Managed Services
# 1063                                             SSAE16
# 1064                                                DLP
# 1065                         Authentication - Vermilion
# 1066                               ISAE3402 - Vermilion
# 1067                                    System recovery
# 1068                                         Monitoring
#
#                                                  Answer Updated date  \
# 0        This is in place for some, but not all systems          NaN
# 1          Privileged accounts granted based on role.            NaN
# 2     Only limited, named systems administrators hav...          NaN
# 3     Access is granted based on employee role.  Fac...          NaN
# 4     Access to systems and resources is role-based....          NaN
# 5     This is handled by the FactSet Systems Enginee...          NaN
# 6     FactSet server administrators grant access con...          NaN
# 7     Employees are issued user IDs specific to the ...          NaN
# 8     Account IDs are only reused if an employee or ...          NaN
# 9     This is true for all network, application and ...          NaN
# 10    Procedures are in place to review employee acc...          NaN
# 11    FactSet periodically reviews all internal and ...          NaN
# 12                                      Within 24 hours          NaN
# 13    FactSet has many clients successfully integrat...          NaN
# 14    The FactSet client software uses an ActiveX co...          NaN
# 15    FactSet is an installed application.  The Fact...          NaN
# 16    The FactSet add-ins for Office can be enabled/...          NaN
# 17    Administrative access is restricted in some ca...          NaN
# 18    FactSet supports many workflows  many of whic...          NaN
# 19    FactSets Security Teams monitor several sourc...          NaN
# 20    FactSet maintains an automated alert system, w...          NaN
# 21    This is in place where appropriate and necessa...    8/26/2017
# 22    No.  As necessary and appropriate.\n\n--\nOn f...    8/26/2017
# 23    Virus checking is in place on production mail ...    8/26/2017
# 24                                         In real time    8/26/2017
# 25                           Auto-updates are employed.    8/26/2017
# 26                                               Weekly    8/26/2017
# 27    Processes are in place to ensure enterprise PC...    8/26/2017
# 28    FactSet regularly scans devices, and auto upda...    8/26/2017
# 29    Yes.  FactSet has anti-malware built into our ...    8/26/2017
# ...                                                 ...          ...
# 1039  Client business users are able to apply indivi...    3/14/2018
# 1040  Hosted application access will be through a Ci...    7/19/2017
# 1041  Clients have no direct access to the critical ...    7/19/2017
# 1042  FactSet manages 100% of its hosting infrastruc...    7/10/2017
# 1043  FactSet's Enterprise Hosting pods, where the <...    7/10/2017
# 1044  <APPLICATION NAME> will be hosted by FactSet i...    6/22/2017
# 1045  FactSet Enterprise Hosting allows for various ...    6/22/2017
# 1046  FactSet Enterprise Hosting includes the option...    6/22/2017
# 1047  DR testing for single-tenant pods would be coo...    6/22/2017
# 1048  The underlying infrastructure that Enterprise ...    11/8/2017
# 1049  Yes.  While FactSets Enterprise Hosting is a ...    10/4/2017
# 1050  Yes.  While FactSets Enterprise Hosting is a ...   10/10/2017
# 1051  FactSet is able to deploy a client environment...    6/22/2017
# 1052  FactSet leverages multiple technologies to pro...    6/22/2017
# 1053  FactSet maintains all technical configurations...    6/22/2017
# 1054  Backups happen using automated technologies (s...    6/22/2017
# 1055  Data is backed up in realtime via Zerto synchr...    3/14/2018
# 1056  The system can remain online during back-ups (...    3/14/2018
# 1057  Failover to data-synchronized backup pods, or ...    6/22/2017
# 1058  For single-tenant hosted Performance and Repor...    3/13/2018
# 1059  FactSet retains all data in the system and doe...    1/22/2018
# 1060  FactSet provides database recovery in the even...    6/22/2017
# 1061  FactSet has a robust FactSet Enterprise System...    1/31/2018
# 1062  FactSet offers the following via our Enterpris...    7/11/2017
# 1063  FactSet's NJ datacenter is SSAE16 certified an...    11/3/2017
# 1064  Access to the environment is based on employee...          NaN
# 1065  Vermilion on FactSet Enterprise Hosting suppor...   12/13/2018
# 1066  FactSet is concluding an ISAE 3402 for Vermili...   12/13/2018
# 1067  FactSet Enterprise Hosting is a fully managed ...    3/14/2018
# 1068  FactSet has its own Central Logging Platform a...    3/14/2018
#
#      Answer provided by  Expiration Date  \
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# 5                   NaN              NaN
# 6                   NaN              NaN
# 7                   NaN              NaN
# 8                   NaN              NaN
# 9                   NaN              NaN
# 10                  NaN              NaN
# 11                  NaN              NaN
# 12                  NaN              NaN
# 13                  NaN              NaN
# 14                  NaN              NaN
# 15                  NaN              NaN
# 16                  NaN              NaN
# 17                  NaN              NaN
# 18                  NaN              NaN
# 19                  NaN              NaN
# 20                  NaN              NaN
# 21                  LCW              NaN
# 22                  LCW              NaN
# 23                  LCW              NaN
# 24                  LCW              NaN
# 25                  LCW              NaN
# 26                  LCW              NaN
# 27                  LCW              NaN
# 28                  LCW              NaN
# 29                  LCW              NaN
# ...                 ...              ...
# 1039                JMD              NaN
# 1040           Gota/Pat              NaN
# 1041           Gota/Pat              NaN
# 1042                JMD              NaN
# 1043                JMD              NaN
# 1044                JMD              NaN
# 1045                JMD              NaN
# 1046                JMD              NaN
# 1047                JMD              NaN
# 1048                JMD              NaN
# 1049                Pat              NaN
# 1050                Pat              NaN
# 1051                JMD              NaN
# 1052                JMD              NaN
# 1053                JMD              NaN
# 1054                JMD              NaN
# 1055                JMD              NaN
# 1056                JMD              NaN
# 1057                JMD              NaN
# 1058                JMD              NaN
# 1059                JMD              NaN
# 1060                JMD              NaN
# 1061                JMD              NaN
# 1062                Pat              NaN
# 1063                LCW              NaN
# 1064                MCW              NaN
# 1065                JMD              NaN
# 1066                JMD              NaN
# 1067                LCW              NaN
# 1068                LCW              NaN
#
#                                             text_concat
# 0     access control Are all system login screens co...
# 1     access control Does your company disable defau...
# 2     access control  Only limited, named systems ad...
# 3     access control policy copy of your Access Cont...
# 4     Access Control,  Please explain who initiates ...
# 5     access control, accounts, Is there a dedicated...
# 6     access control, authorization, system admin Wh...
# 7     access control, employee management system, le...
# 8     access control, password policy Does your comp...
# 9     access control, password policy, encryption Do...
# 10    Access Control, Review, access review Access C...
# 11    access control, review, log When was the last ...
# 12    access removal Provide the time frame for remo...
# 13    accounting system, upload, holdings, import, e...
# 14    ActiveX ActiveX The FactSet client software us...
# 15    ActiveX, HTML, Flash, Java Is any specific des...
# 16    addins, add-ins Concerning FactSet installing ...
# 17    admin access, admin rights, administrator acce...
# 18    alert Does the application provide alerts, not...
# 19    alert, vulnerability Do you receive CERT Advis...
# 20    alerting Does the Hosting Provider review viol...
# 21    Antivirus, anti-virus, anti-malware, antimalwa...
# 22    Antivirus, anti-virus, anti-malware, antimalwa...
# 23    Antivirus, anti-virus, anti-malware, antimalwa...
# 24    Antivirus, anti-virus, anti-malware, antimalwa...
# 25    Antivirus, anti-virus, anti-malware, antimalwa...
# 26    Antivirus, anti-virus, anti-malware, antimalwa...
# 27    Antivirus, anti-virus, anti-malware, antimalwa...
# 28    Antivirus, anti-virus, anti-malware, antimalwa...
# 29    Antivirus, anti-virus, anti-malware, antimalwa...
# ...                                                 ...
# 1039   Entitlements - Vermilion Client business user...
# 1040   Browser requirements Hosted application acces...
# 1041   Access Clients have no direct access to the c...
# 1042   Outsourcing FactSet manages 100% of its hosti...
# 1043   Data separation FactSet's Enterprise Hosting ...
# 1044   Virtualization Possible? <APPLICATION NAME> w...
# 1045   BCP/DR - overview FactSet Enterprise Hosting ...
# 1046   BCP/DR - overview FactSet Enterprise Hosting ...
# 1047   BCP/DR - Testing DR testing for single-tenant...
# 1048   BCP/DR - Testing - conducted in the last 12 m...
# 1049   BCP/DR - Testing - conducted in the last 12 m...
# 1050   BCP/DR - Testing - conducted in the last 12 m...
# 1051   BCP/DR - overview FactSet is able to deploy a...
# 1052   BCP/DR - back-ups FactSet leverages multiple ...
# 1053   Professional Services FactSet maintains all t...
# 1054   BCP/DR - back-ups Backups happen using automa...
# 1055   BCP/DR - back-ups frequency Data is backed up...
# 1056   BCP/DR - back-ups The system can remain onlin...
# 1057   BCP/DR - restore Failover to data-synchronize...
# 1058   BCP/DR - recovery capabilty For single-tenant...
# 1059   Information retention FactSet retains all dat...
# 1060   Data restoration FactSet provides database re...
# 1061   Security Controls FactSet has a robust FactSe...
# 1062   Managed Services FactSet offers the following...
# 1063   SSAE16 FactSet's NJ datacenter is SSAE16 cert...
# 1064   DLP Access to the environment is based on emp...
# 1065   Authentication - Vermilion Vermilion on FactS...
# 1066   ISAE3402 - Vermilion FactSet is concluding an...
# 1067   System recovery FactSet Enterprise Hosting is...
# 1068   Monitoring FactSet has its own Central Loggin...
#
# [1069 rows x 7 columns]

# %%
X_master_test = trc_test_data.loc[:, 'text_concat']

# %%
#Create Document-term Matrices with CountVectorizer()
vect = CountVectorizer(stop_words ='english', analyzer=split_into_lemmas, decode_error='replace', ngram_range=(1,1), min_df=3)
vect.fit(X_train)
X_train_dtm = vect.transform(X_train)
# X_test_dtm = vect.transform(X_test)
X_master_test_dtm = vect.transform(X_master_test)

#Use Naive Bayes to predict sig_class_num
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_master_test_dtm)

# %%
# Convert y_pred_class results into a dataframe
class_pred = pd.DataFrame(y_pred_class)

# %%
trc_with_class_pred = pd.concat([trc_test_data, class_pred], axis=1)

# %%
trc_with_class_pred
# Out:
#                                                     Tag  \
# 0                                        access control
# 1                                        access control
# 2                                        access control
# 3                                 access control policy
# 4                                      Access Control,
# 5                             access control, accounts,
# 6           access control, authorization, system admin
# 7     access control, employee management system, le...
# 8                       access control, password policy
# 9           access control, password policy, encryption
# 10                Access Control, Review, access review
# 11                          access control, review, log
# 12                                       access removal
# 13    accounting system, upload, holdings, import, e...
# 14                                              ActiveX
# 15                           ActiveX, HTML, Flash, Java
# 16                                      addins, add-ins
# 17    admin access, admin rights, administrator acce...
# 18                                                alert
# 19                                 alert, vulnerability
# 20                                             alerting
# 21     Antivirus, anti-virus, anti-malware, antimalware
# 22     Antivirus, anti-virus, anti-malware, antimalware
# 23     Antivirus, anti-virus, anti-malware, antimalware
# 24     Antivirus, anti-virus, anti-malware, antimalware
# 25     Antivirus, anti-virus, anti-malware, antimalware
# 26     Antivirus, anti-virus, anti-malware, antimalware
# 27     Antivirus, anti-virus, anti-malware, antimalware
# 28     Antivirus, anti-virus, anti-malware, antimalware
# 29     Antivirus, anti-virus, anti-malware, antimalware
# ...                                                 ...
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
#
#                                                Question  \
# 0     Are all system login screens configured to dis...
# 1     Does your company disable default privileged a...
# 2
# 3        copy of your Access Control Policy and process
# 4     Please explain who initiates and approves the ...
# 5     Is there a dedicated team tasked with create/a...
# 6                                 Who authorizes access
# 7     How are your internal users (employees) grante...
# 8     Does your company enforce a user account creat...
# 9     Does your company require all passwords, inclu...
# 10    Access Control\n\nThe Service Provider will co...
# 11    When was the last time an application/technica...
# 12    Provide the time frame for removing access of ...
# 13                 How many of your clients use PORTIA?
# 14                                              ActiveX
# 15    Is any specific desktop / browser software req...
# 16    Concerning FactSet installing (setup) is it po...
# 17    Does the company restrict administrative acces...
# 18    Does the application provide alerts, notices, ...
# 19    Do you receive CERT Advisories from Carnegie M...
# 20    Does the Hosting Provider review violation rep...
# 21                 Do you use Anti-virus? Anti-malware?
# 22       Do you use anti-virus on ALL systems?  Explain
# 23              Do you use anti-virus on Email Systems?
# 24    How often are workstation anti-virus scans con...
# 25             Are all virus definitions updated daily?
# 26        How often are FULL antivirus scans performed?
# 27               Describe the signature update process.
# 28        How does FactSet prevent cross-contamination?
# 29    Are the malicious code prevention software upd...
# ...                                                 ...
# 1039                           Entitlements - Vermilion
# 1040                               Browser requirements
# 1041                                             Access
# 1042                                        Outsourcing
# 1043                                    Data separation
# 1044                           Virtualization Possible?
# 1045                                  BCP/DR - overview
# 1046                                  BCP/DR - overview
# 1047                                   BCP/DR - Testing
# 1048  BCP/DR - Testing - conducted in the last 12 mo...
# 1049  BCP/DR - Testing - conducted in the last 12 mo...
# 1050  BCP/DR - Testing - conducted in the last 12 mo...
# 1051                                  BCP/DR - overview
# 1052                                  BCP/DR - back-ups
# 1053                              Professional Services
# 1054                                  BCP/DR - back-ups
# 1055                        BCP/DR - back-ups frequency
# 1056                                  BCP/DR - back-ups
# 1057                                   BCP/DR - restore
# 1058                        BCP/DR - recovery capabilty
# 1059                              Information retention
# 1060                                   Data restoration
# 1061                                  Security Controls
# 1062                                   Managed Services
# 1063                                             SSAE16
# 1064                                                DLP
# 1065                         Authentication - Vermilion
# 1066                               ISAE3402 - Vermilion
# 1067                                    System recovery
# 1068                                         Monitoring
#
#                                                  Answer Updated date  \
# 0        This is in place for some, but not all systems          NaN
# 1          Privileged accounts granted based on role.            NaN
# 2     Only limited, named systems administrators hav...          NaN
# 3     Access is granted based on employee role.  Fac...          NaN
# 4     Access to systems and resources is role-based....          NaN
# 5     This is handled by the FactSet Systems Enginee...          NaN
# 6     FactSet server administrators grant access con...          NaN
# 7     Employees are issued user IDs specific to the ...          NaN
# 8     Account IDs are only reused if an employee or ...          NaN
# 9     This is true for all network, application and ...          NaN
# 10    Procedures are in place to review employee acc...          NaN
# 11    FactSet periodically reviews all internal and ...          NaN
# 12                                      Within 24 hours          NaN
# 13    FactSet has many clients successfully integrat...          NaN
# 14    The FactSet client software uses an ActiveX co...          NaN
# 15    FactSet is an installed application.  The Fact...          NaN
# 16    The FactSet add-ins for Office can be enabled/...          NaN
# 17    Administrative access is restricted in some ca...          NaN
# 18    FactSet supports many workflows  many of whic...          NaN
# 19    FactSets Security Teams monitor several sourc...          NaN
# 20    FactSet maintains an automated alert system, w...          NaN
# 21    This is in place where appropriate and necessa...    8/26/2017
# 22    No.  As necessary and appropriate.\n\n--\nOn f...    8/26/2017
# 23    Virus checking is in place on production mail ...    8/26/2017
# 24                                         In real time    8/26/2017
# 25                           Auto-updates are employed.    8/26/2017
# 26                                               Weekly    8/26/2017
# 27    Processes are in place to ensure enterprise PC...    8/26/2017
# 28    FactSet regularly scans devices, and auto upda...    8/26/2017
# 29    Yes.  FactSet has anti-malware built into our ...    8/26/2017
# ...                                                 ...          ...
# 1039  Client business users are able to apply indivi...    3/14/2018
# 1040  Hosted application access will be through a Ci...    7/19/2017
# 1041  Clients have no direct access to the critical ...    7/19/2017
# 1042  FactSet manages 100% of its hosting infrastruc...    7/10/2017
# 1043  FactSet's Enterprise Hosting pods, where the <...    7/10/2017
# 1044  <APPLICATION NAME> will be hosted by FactSet i...    6/22/2017
# 1045  FactSet Enterprise Hosting allows for various ...    6/22/2017
# 1046  FactSet Enterprise Hosting includes the option...    6/22/2017
# 1047  DR testing for single-tenant pods would be coo...    6/22/2017
# 1048  The underlying infrastructure that Enterprise ...    11/8/2017
# 1049  Yes.  While FactSets Enterprise Hosting is a ...    10/4/2017
# 1050  Yes.  While FactSets Enterprise Hosting is a ...   10/10/2017
# 1051  FactSet is able to deploy a client environment...    6/22/2017
# 1052  FactSet leverages multiple technologies to pro...    6/22/2017
# 1053  FactSet maintains all technical configurations...    6/22/2017
# 1054  Backups happen using automated technologies (s...    6/22/2017
# 1055  Data is backed up in realtime via Zerto synchr...    3/14/2018
# 1056  The system can remain online during back-ups (...    3/14/2018
# 1057  Failover to data-synchronized backup pods, or ...    6/22/2017
# 1058  For single-tenant hosted Performance and Repor...    3/13/2018
# 1059  FactSet retains all data in the system and doe...    1/22/2018
# 1060  FactSet provides database recovery in the even...    6/22/2017
# 1061  FactSet has a robust FactSet Enterprise System...    1/31/2018
# 1062  FactSet offers the following via our Enterpris...    7/11/2017
# 1063  FactSet's NJ datacenter is SSAE16 certified an...    11/3/2017
# 1064  Access to the environment is based on employee...          NaN
# 1065  Vermilion on FactSet Enterprise Hosting suppor...   12/13/2018
# 1066  FactSet is concluding an ISAE 3402 for Vermili...   12/13/2018
# 1067  FactSet Enterprise Hosting is a fully managed ...    3/14/2018
# 1068  FactSet has its own Central Logging Platform a...    3/14/2018
#
#      Answer provided by  Expiration Date  \
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# 5                   NaN              NaN
# 6                   NaN              NaN
# 7                   NaN              NaN
# 8                   NaN              NaN
# 9                   NaN              NaN
# 10                  NaN              NaN
# 11                  NaN              NaN
# 12                  NaN              NaN
# 13                  NaN              NaN
# 14                  NaN              NaN
# 15                  NaN              NaN
# 16                  NaN              NaN
# 17                  NaN              NaN
# 18                  NaN              NaN
# 19                  NaN              NaN
# 20                  NaN              NaN
# 21                  LCW              NaN
# 22                  LCW              NaN
# 23                  LCW              NaN
# 24                  LCW              NaN
# 25                  LCW              NaN
# 26                  LCW              NaN
# 27                  LCW              NaN
# 28                  LCW              NaN
# 29                  LCW              NaN
# ...                 ...              ...
# 1039                JMD              NaN
# 1040           Gota/Pat              NaN
# 1041           Gota/Pat              NaN
# 1042                JMD              NaN
# 1043                JMD              NaN
# 1044                JMD              NaN
# 1045                JMD              NaN
# 1046                JMD              NaN
# 1047                JMD              NaN
# 1048                JMD              NaN
# 1049                Pat              NaN
# 1050                Pat              NaN
# 1051                JMD              NaN
# 1052                JMD              NaN
# 1053                JMD              NaN
# 1054                JMD              NaN
# 1055                JMD              NaN
# 1056                JMD              NaN
# 1057                JMD              NaN
# 1058                JMD              NaN
# 1059                JMD              NaN
# 1060                JMD              NaN
# 1061                JMD              NaN
# 1062                Pat              NaN
# 1063                LCW              NaN
# 1064                MCW              NaN
# 1065                JMD              NaN
# 1066                JMD              NaN
# 1067                LCW              NaN
# 1068                LCW              NaN
#
#                                             text_concat   0
# 0     access control Are all system login screens co...   8
# 1     access control Does your company disable defau...   8
# 2     access control  Only limited, named systems ad...   8
# 3     access control policy copy of your Access Cont...   8
# 4     Access Control,  Please explain who initiates ...   8
# 5     access control, accounts, Is there a dedicated...   8
# 6     access control, authorization, system admin Wh...   8
# 7     access control, employee management system, le...   8
# 8     access control, password policy Does your comp...   8
# 9     access control, password policy, encryption Do...   8
# 10    Access Control, Review, access review Access C...   8
# 11    access control, review, log When was the last ...   1
# 12    access removal Provide the time frame for remo...   8
# 13    accounting system, upload, holdings, import, e...   4
# 14    ActiveX ActiveX The FactSet client software us...   1
# 15    ActiveX, HTML, Flash, Java Is any specific des...   7
# 16    addins, add-ins Concerning FactSet installing ...   1
# 17    admin access, admin rights, administrator acce...   8
# 18    alert Does the application provide alerts, not...   1
# 19    alert, vulnerability Do you receive CERT Advis...  14
# 20    alerting Does the Hosting Provider review viol...   1
# 21    Antivirus, anti-virus, anti-malware, antimalwa...   5
# 22    Antivirus, anti-virus, anti-malware, antimalwa...   1
# 23    Antivirus, anti-virus, anti-malware, antimalwa...   7
# 24    Antivirus, anti-virus, anti-malware, antimalwa...  13
# 25    Antivirus, anti-virus, anti-malware, antimalwa...   5
# 26    Antivirus, anti-virus, anti-malware, antimalwa...  13
# 27    Antivirus, anti-virus, anti-malware, antimalwa...  16
# 28    Antivirus, anti-virus, anti-malware, antimalwa...   7
# 29    Antivirus, anti-virus, anti-malware, antimalwa...   1
# ...                                                 ...  ..
# 1039   Entitlements - Vermilion Client business user...   4
# 1040   Browser requirements Hosted application acces...   2
# 1041   Access Clients have no direct access to the c...   1
# 1042   Outsourcing FactSet manages 100% of its hosti...   2
# 1043   Data separation FactSet's Enterprise Hosting ...   4
# 1044   Virtualization Possible? <APPLICATION NAME> w...   1
# 1045   BCP/DR - overview FactSet Enterprise Hosting ...   2
# 1046   BCP/DR - overview FactSet Enterprise Hosting ...   2
# 1047   BCP/DR - Testing DR testing for single-tenant...   2
# 1048   BCP/DR - Testing - conducted in the last 12 m...   1
# 1049   BCP/DR - Testing - conducted in the last 12 m...   1
# 1050   BCP/DR - Testing - conducted in the last 12 m...   1
# 1051   BCP/DR - overview FactSet is able to deploy a...   4
# 1052   BCP/DR - back-ups FactSet leverages multiple ...   4
# 1053   Professional Services FactSet maintains all t...   2
# 1054   BCP/DR - back-ups Backups happen using automa...   1
# 1055   BCP/DR - back-ups frequency Data is backed up...   1
# 1056   BCP/DR - back-ups The system can remain onlin...   2
# 1057   BCP/DR - restore Failover to data-synchronize...   7
# 1058   BCP/DR - recovery capabilty For single-tenant...   2
# 1059   Information retention FactSet retains all dat...   1
# 1060   Data restoration FactSet provides database re...   4
# 1061   Security Controls FactSet has a robust FactSe...   1
# 1062   Managed Services FactSet offers the following...   2
# 1063   SSAE16 FactSet's NJ datacenter is SSAE16 cert...  14
# 1064   DLP Access to the environment is based on emp...   7
# 1065   Authentication - Vermilion Vermilion on FactS...   9
# 1066   ISAE3402 - Vermilion FactSet is concluding an...   2
# 1067   System recovery FactSet Enterprise Hosting is...   2
# 1068   Monitoring FactSet has its own Central Loggin...   2
#
# [1069 rows x 8 columns]

# %%
#Naming the last columns to class_num

trc_with_class_pred.columns = ['Tag','Question','Answer','Updated date','Answer provided by','Expiration Date','text_concat','pred_class_num']

# %%
trc_with_class_pred.loc[:, 'pred_class'] = trc_with_class_pred.loc[:, 'pred_class_num'].map({
    1:'Application Security',
    2:'Operations Management',
    3:'Business Resiliency',
    4:'Asset and Information Management',
    5:'Server Security',
    6:'Physical and Environment',
    7:'End User Device Security',
    8:'Access Control',
    9:'Network Security',
    10:'Incident Event & Communication Management',
    11:'Risk Assessment',
    12:'Security Policy',
    13:'Threat Management',
    14:'Compliance',
    15:'Human Resource Security',
    16:'Privacy',
    17:'Organizational Security'
})

# %%
trc_with_class_pred
# Out:
#                                                     Tag  \
# 0                                        access control
# 1                                        access control
# 2                                        access control
# 3                                 access control policy
# 4                                      Access Control,
# 5                             access control, accounts,
# 6           access control, authorization, system admin
# 7     access control, employee management system, le...
# 8                       access control, password policy
# 9           access control, password policy, encryption
# 10                Access Control, Review, access review
# 11                          access control, review, log
# 12                                       access removal
# 13    accounting system, upload, holdings, import, e...
# 14                                              ActiveX
# 15                           ActiveX, HTML, Flash, Java
# 16                                      addins, add-ins
# 17    admin access, admin rights, administrator acce...
# 18                                                alert
# 19                                 alert, vulnerability
# 20                                             alerting
# 21     Antivirus, anti-virus, anti-malware, antimalware
# 22     Antivirus, anti-virus, anti-malware, antimalware
# 23     Antivirus, anti-virus, anti-malware, antimalware
# 24     Antivirus, anti-virus, anti-malware, antimalware
# 25     Antivirus, anti-virus, anti-malware, antimalware
# 26     Antivirus, anti-virus, anti-malware, antimalware
# 27     Antivirus, anti-virus, anti-malware, antimalware
# 28     Antivirus, anti-virus, anti-malware, antimalware
# 29     Antivirus, anti-virus, anti-malware, antimalware
# ...                                                 ...
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
#
#                                                Question  \
# 0     Are all system login screens configured to dis...
# 1     Does your company disable default privileged a...
# 2
# 3        copy of your Access Control Policy and process
# 4     Please explain who initiates and approves the ...
# 5     Is there a dedicated team tasked with create/a...
# 6                                 Who authorizes access
# 7     How are your internal users (employees) grante...
# 8     Does your company enforce a user account creat...
# 9     Does your company require all passwords, inclu...
# 10    Access Control\n\nThe Service Provider will co...
# 11    When was the last time an application/technica...
# 12    Provide the time frame for removing access of ...
# 13                 How many of your clients use PORTIA?
# 14                                              ActiveX
# 15    Is any specific desktop / browser software req...
# 16    Concerning FactSet installing (setup) is it po...
# 17    Does the company restrict administrative acces...
# 18    Does the application provide alerts, notices, ...
# 19    Do you receive CERT Advisories from Carnegie M...
# 20    Does the Hosting Provider review violation rep...
# 21                 Do you use Anti-virus? Anti-malware?
# 22       Do you use anti-virus on ALL systems?  Explain
# 23              Do you use anti-virus on Email Systems?
# 24    How often are workstation anti-virus scans con...
# 25             Are all virus definitions updated daily?
# 26        How often are FULL antivirus scans performed?
# 27               Describe the signature update process.
# 28        How does FactSet prevent cross-contamination?
# 29    Are the malicious code prevention software upd...
# ...                                                 ...
# 1039                           Entitlements - Vermilion
# 1040                               Browser requirements
# 1041                                             Access
# 1042                                        Outsourcing
# 1043                                    Data separation
# 1044                           Virtualization Possible?
# 1045                                  BCP/DR - overview
# 1046                                  BCP/DR - overview
# 1047                                   BCP/DR - Testing
# 1048  BCP/DR - Testing - conducted in the last 12 mo...
# 1049  BCP/DR - Testing - conducted in the last 12 mo...
# 1050  BCP/DR - Testing - conducted in the last 12 mo...
# 1051                                  BCP/DR - overview
# 1052                                  BCP/DR - back-ups
# 1053                              Professional Services
# 1054                                  BCP/DR - back-ups
# 1055                        BCP/DR - back-ups frequency
# 1056                                  BCP/DR - back-ups
# 1057                                   BCP/DR - restore
# 1058                        BCP/DR - recovery capabilty
# 1059                              Information retention
# 1060                                   Data restoration
# 1061                                  Security Controls
# 1062                                   Managed Services
# 1063                                             SSAE16
# 1064                                                DLP
# 1065                         Authentication - Vermilion
# 1066                               ISAE3402 - Vermilion
# 1067                                    System recovery
# 1068                                         Monitoring
#
#                                                  Answer Updated date  \
# 0        This is in place for some, but not all systems          NaN
# 1          Privileged accounts granted based on role.            NaN
# 2     Only limited, named systems administrators hav...          NaN
# 3     Access is granted based on employee role.  Fac...          NaN
# 4     Access to systems and resources is role-based....          NaN
# 5     This is handled by the FactSet Systems Enginee...          NaN
# 6     FactSet server administrators grant access con...          NaN
# 7     Employees are issued user IDs specific to the ...          NaN
# 8     Account IDs are only reused if an employee or ...          NaN
# 9     This is true for all network, application and ...          NaN
# 10    Procedures are in place to review employee acc...          NaN
# 11    FactSet periodically reviews all internal and ...          NaN
# 12                                      Within 24 hours          NaN
# 13    FactSet has many clients successfully integrat...          NaN
# 14    The FactSet client software uses an ActiveX co...          NaN
# 15    FactSet is an installed application.  The Fact...          NaN
# 16    The FactSet add-ins for Office can be enabled/...          NaN
# 17    Administrative access is restricted in some ca...          NaN
# 18    FactSet supports many workflows  many of whic...          NaN
# 19    FactSets Security Teams monitor several sourc...          NaN
# 20    FactSet maintains an automated alert system, w...          NaN
# 21    This is in place where appropriate and necessa...    8/26/2017
# 22    No.  As necessary and appropriate.\n\n--\nOn f...    8/26/2017
# 23    Virus checking is in place on production mail ...    8/26/2017
# 24                                         In real time    8/26/2017
# 25                           Auto-updates are employed.    8/26/2017
# 26                                               Weekly    8/26/2017
# 27    Processes are in place to ensure enterprise PC...    8/26/2017
# 28    FactSet regularly scans devices, and auto upda...    8/26/2017
# 29    Yes.  FactSet has anti-malware built into our ...    8/26/2017
# ...                                                 ...          ...
# 1039  Client business users are able to apply indivi...    3/14/2018
# 1040  Hosted application access will be through a Ci...    7/19/2017
# 1041  Clients have no direct access to the critical ...    7/19/2017
# 1042  FactSet manages 100% of its hosting infrastruc...    7/10/2017
# 1043  FactSet's Enterprise Hosting pods, where the <...    7/10/2017
# 1044  <APPLICATION NAME> will be hosted by FactSet i...    6/22/2017
# 1045  FactSet Enterprise Hosting allows for various ...    6/22/2017
# 1046  FactSet Enterprise Hosting includes the option...    6/22/2017
# 1047  DR testing for single-tenant pods would be coo...    6/22/2017
# 1048  The underlying infrastructure that Enterprise ...    11/8/2017
# 1049  Yes.  While FactSets Enterprise Hosting is a ...    10/4/2017
# 1050  Yes.  While FactSets Enterprise Hosting is a ...   10/10/2017
# 1051  FactSet is able to deploy a client environment...    6/22/2017
# 1052  FactSet leverages multiple technologies to pro...    6/22/2017
# 1053  FactSet maintains all technical configurations...    6/22/2017
# 1054  Backups happen using automated technologies (s...    6/22/2017
# 1055  Data is backed up in realtime via Zerto synchr...    3/14/2018
# 1056  The system can remain online during back-ups (...    3/14/2018
# 1057  Failover to data-synchronized backup pods, or ...    6/22/2017
# 1058  For single-tenant hosted Performance and Repor...    3/13/2018
# 1059  FactSet retains all data in the system and doe...    1/22/2018
# 1060  FactSet provides database recovery in the even...    6/22/2017
# 1061  FactSet has a robust FactSet Enterprise System...    1/31/2018
# 1062  FactSet offers the following via our Enterpris...    7/11/2017
# 1063  FactSet's NJ datacenter is SSAE16 certified an...    11/3/2017
# 1064  Access to the environment is based on employee...          NaN
# 1065  Vermilion on FactSet Enterprise Hosting suppor...   12/13/2018
# 1066  FactSet is concluding an ISAE 3402 for Vermili...   12/13/2018
# 1067  FactSet Enterprise Hosting is a fully managed ...    3/14/2018
# 1068  FactSet has its own Central Logging Platform a...    3/14/2018
#
#      Answer provided by  Expiration Date  \
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# 5                   NaN              NaN
# 6                   NaN              NaN
# 7                   NaN              NaN
# 8                   NaN              NaN
# 9                   NaN              NaN
# 10                  NaN              NaN
# 11                  NaN              NaN
# 12                  NaN              NaN
# 13                  NaN              NaN
# 14                  NaN              NaN
# 15                  NaN              NaN
# 16                  NaN              NaN
# 17                  NaN              NaN
# 18                  NaN              NaN
# 19                  NaN              NaN
# 20                  NaN              NaN
# 21                  LCW              NaN
# 22                  LCW              NaN
# 23                  LCW              NaN
# 24                  LCW              NaN
# 25                  LCW              NaN
# 26                  LCW              NaN
# 27                  LCW              NaN
# 28                  LCW              NaN
# 29                  LCW              NaN
# ...                 ...              ...
# 1039                JMD              NaN
# 1040           Gota/Pat              NaN
# 1041           Gota/Pat              NaN
# 1042                JMD              NaN
# 1043                JMD              NaN
# 1044                JMD              NaN
# 1045                JMD              NaN
# 1046                JMD              NaN
# 1047                JMD              NaN
# 1048                JMD              NaN
# 1049                Pat              NaN
# 1050                Pat              NaN
# 1051                JMD              NaN
# 1052                JMD              NaN
# 1053                JMD              NaN
# 1054                JMD              NaN
# 1055                JMD              NaN
# 1056                JMD              NaN
# 1057                JMD              NaN
# 1058                JMD              NaN
# 1059                JMD              NaN
# 1060                JMD              NaN
# 1061                JMD              NaN
# 1062                Pat              NaN
# 1063                LCW              NaN
# 1064                MCW              NaN
# 1065                JMD              NaN
# 1066                JMD              NaN
# 1067                LCW              NaN
# 1068                LCW              NaN
#
#                                             text_concat  pred_class_num  \
# 0     access control Are all system login screens co...               8
# 1     access control Does your company disable defau...               8
# 2     access control  Only limited, named systems ad...               8
# 3     access control policy copy of your Access Cont...               8
# 4     Access Control,  Please explain who initiates ...               8
# 5     access control, accounts, Is there a dedicated...               8
# 6     access control, authorization, system admin Wh...               8
# 7     access control, employee management system, le...               8
# 8     access control, password policy Does your comp...               8
# 9     access control, password policy, encryption Do...               8
# 10    Access Control, Review, access review Access C...               8
# 11    access control, review, log When was the last ...               1
# 12    access removal Provide the time frame for remo...               8
# 13    accounting system, upload, holdings, import, e...               4
# 14    ActiveX ActiveX The FactSet client software us...               1
# 15    ActiveX, HTML, Flash, Java Is any specific des...               7
# 16    addins, add-ins Concerning FactSet installing ...               1
# 17    admin access, admin rights, administrator acce...               8
# 18    alert Does the application provide alerts, not...               1
# 19    alert, vulnerability Do you receive CERT Advis...              14
# 20    alerting Does the Hosting Provider review viol...               1
# 21    Antivirus, anti-virus, anti-malware, antimalwa...               5
# 22    Antivirus, anti-virus, anti-malware, antimalwa...               1
# 23    Antivirus, anti-virus, anti-malware, antimalwa...               7
# 24    Antivirus, anti-virus, anti-malware, antimalwa...              13
# 25    Antivirus, anti-virus, anti-malware, antimalwa...               5
# 26    Antivirus, anti-virus, anti-malware, antimalwa...              13
# 27    Antivirus, anti-virus, anti-malware, antimalwa...              16
# 28    Antivirus, anti-virus, anti-malware, antimalwa...               7
# 29    Antivirus, anti-virus, anti-malware, antimalwa...               1
# ...                                                 ...             ...
# 1039   Entitlements - Vermilion Client business user...               4
# 1040   Browser requirements Hosted application acces...               2
# 1041   Access Clients have no direct access to the c...               1
# 1042   Outsourcing FactSet manages 100% of its hosti...               2
# 1043   Data separation FactSet's Enterprise Hosting ...               4
# 1044   Virtualization Possible? <APPLICATION NAME> w...               1
# 1045   BCP/DR - overview FactSet Enterprise Hosting ...               2
# 1046   BCP/DR - overview FactSet Enterprise Hosting ...               2
# 1047   BCP/DR - Testing DR testing for single-tenant...               2
# 1048   BCP/DR - Testing - conducted in the last 12 m...               1
# 1049   BCP/DR - Testing - conducted in the last 12 m...               1
# 1050   BCP/DR - Testing - conducted in the last 12 m...               1
# 1051   BCP/DR - overview FactSet is able to deploy a...               4
# 1052   BCP/DR - back-ups FactSet leverages multiple ...               4
# 1053   Professional Services FactSet maintains all t...               2
# 1054   BCP/DR - back-ups Backups happen using automa...               1
# 1055   BCP/DR - back-ups frequency Data is backed up...               1
# 1056   BCP/DR - back-ups The system can remain onlin...               2
# 1057   BCP/DR - restore Failover to data-synchronize...               7
# 1058   BCP/DR - recovery capabilty For single-tenant...               2
# 1059   Information retention FactSet retains all dat...               1
# 1060   Data restoration FactSet provides database re...               4
# 1061   Security Controls FactSet has a robust FactSe...               1
# 1062   Managed Services FactSet offers the following...               2
# 1063   SSAE16 FactSet's NJ datacenter is SSAE16 cert...              14
# 1064   DLP Access to the environment is based on emp...               7
# 1065   Authentication - Vermilion Vermilion on FactS...               9
# 1066   ISAE3402 - Vermilion FactSet is concluding an...               2
# 1067   System recovery FactSet Enterprise Hosting is...               2
# 1068   Monitoring FactSet has its own Central Loggin...               2
#
#                             pred_class
# 0                       Access Control
# 1                       Access Control
# 2                       Access Control
# 3                       Access Control
# 4                       Access Control
# 5                       Access Control
# 6                       Access Control
# 7                       Access Control
# 8                       Access Control
# 9                       Access Control
# 10                      Access Control
# 11                Application Security
# 12                      Access Control
# 13    Asset and Information Management
# 14                Application Security
# 15            End User Device Security
# 16                Application Security
# 17                      Access Control
# 18                Application Security
# 19                          Compliance
# 20                Application Security
# 21                     Server Security
# 22                Application Security
# 23            End User Device Security
# 24                   Threat Management
# 25                     Server Security
# 26                   Threat Management
# 27                             Privacy
# 28            End User Device Security
# 29                Application Security
# ...                                ...
# 1039  Asset and Information Management
# 1040             Operations Management
# 1041              Application Security
# 1042             Operations Management
# 1043  Asset and Information Management
# 1044              Application Security
# 1045             Operations Management
# 1046             Operations Management
# 1047             Operations Management
# 1048              Application Security
# 1049              Application Security
# 1050              Application Security
# 1051  Asset and Information Management
# 1052  Asset and Information Management
# 1053             Operations Management
# 1054              Application Security
# 1055              Application Security
# 1056             Operations Management
# 1057          End User Device Security
# 1058             Operations Management
# 1059              Application Security
# 1060  Asset and Information Management
# 1061              Application Security
# 1062             Operations Management
# 1063                        Compliance
# 1064          End User Device Security
# 1065                  Network Security
# 1066             Operations Management
# 1067             Operations Management
# 1068             Operations Management
#
# [1069 rows x 9 columns]

# %%
trc_with_class_pred.to_csv('./data/trc_pred_class.csv')
